# %%
import json
import pretty_midi as pm
import pandas as pd
from pathlib import Path

# %%
#virtuoso dataframe (i produce parsing the folders of the dataset)
virtuoso_df = pd.read_pickle("performance_dataframe.pkl")

#maestro dataframe (from google)
maestro_df = pd.read_json('maestro-v2.0.0.json')

# %%
virtuoso_df.head()
# Out:
#   author              folder                         midi2midi_alignment_path  \
# 0   Bach  Bach/Fugue/bwv_846       Bach/Fugue/bwv_846/Shi05_infer_corresp.txt
# 1   Bach  Bach/Fugue/bwv_848  Bach/Fugue/bwv_848/Denisova06_infer_corresp.txt
# 2   Bach  Bach/Fugue/bwv_848       Bach/Fugue/bwv_848/Lee01_infer_corresp.txt
# 3   Bach  Bach/Fugue/bwv_848     Bach/Fugue/bwv_848/LeeSH01_infer_corresp.txt
# 4   Bach  Bach/Fugue/bwv_848       Bach/Fugue/bwv_848/Lin04_infer_corresp.txt
#
#                  performed_midi_path   performer  \
# 0       Bach/Fugue/bwv_846/Shi05.mid       Shi05
# 1  Bach/Fugue/bwv_848/Denisova06.mid  Denisova06
# 2       Bach/Fugue/bwv_848/Lee01.mid       Lee01
# 3     Bach/Fugue/bwv_848/LeeSH01.mid     LeeSH01
# 4       Bach/Fugue/bwv_848/Lin04.mid       Lin04
#
#                             score2midi_alignment  \
# 0       Bach/Fugue/bwv_846/Shi05_infer_match.txt
# 1  Bach/Fugue/bwv_848/Denisova06_infer_match.txt
# 2       Bach/Fugue/bwv_848/Lee01_infer_match.txt
# 3     Bach/Fugue/bwv_848/LeeSH01_infer_match.txt
# 4       Bach/Fugue/bwv_848/Lin04_infer_match.txt
#
#                        score_midi_path  \
# 0  Bach/Fugue/bwv_846/midi_cleaned.mid
# 1  Bach/Fugue/bwv_848/midi_cleaned.mid
# 2  Bach/Fugue/bwv_848/midi_cleaned.mid
# 3  Bach/Fugue/bwv_848/midi_cleaned.mid
# 4  Bach/Fugue/bwv_848/midi_cleaned.mid
#
#                                  score_xml_path          title
# 0  Bach/Fugue/bwv_846/musicxml_cleaned.musicxml  Fugue_bwv_846
# 1  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848
# 2  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848
# 3  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848
# 4  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848

# %%
maestro_df.head()
# Out:
#                                       audio_filename  canonical_composer  \
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...          Alban Berg
# 1  2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...          Alban Berg
# 2  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...          Alban Berg
# 3  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...  Alexander Scriabin
# 4  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...  Alexander Scriabin
#
#                  canonical_title    duration  \
# 0                   Sonata Op. 1  698.661160
# 1                   Sonata Op. 1  759.518471
# 2                   Sonata Op. 1  464.649433
# 3  24 Preludes Op. 11, No. 13-24  872.640588
# 4               3 Etudes, Op. 65  397.857508
#
#                                        midi_filename       split  year
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...       train  2018
# 1  2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...       train  2008
# 2  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...       train  2017
# 3  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...       train  2004
# 4  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...  validation  2006

# %% [markdown]
# ## Some scripts for the automatic alignment

# %%
MAESTRO_BPATH = Path("../datasets/maestro-v2.0.0/")  #you need to download the maestro dataset from https://magenta.tensorflow.org/datasets/maestro
VIRTUOSO_BPATH = Path("./")

def get_midi_notes(midi,start = 0): # get all midi notes ordered
    #extract notes looping through the instrument
    notes_all = [(note.start, note.end, note.pitch) for instrument in midi.instruments for note in instrument.notes if note.start>=start]
    #order notes according to onset and pitch
    return sorted(notes_all, key = lambda x: (x[0],x[2]))

def normalize_midi_notes(notes): # remove the initial silence in the midi 
    #get the onset of the first midi note
    first = notes[0][0]
    #subtract the first to all the tempos
    return [(n[0]-first,n[1]-first,n[2]) for i,n in enumerate(notes)]

def path2normmidinotes(base_path,midi_path,start = 0): #function to add the normnilized notes to the dataframes
    midi = pm.PrettyMIDI(str(Path(base_path,midi_path)))
    return normalize_midi_notes(get_midi_notes(midi,start = start))


#We add the normalized note to the df instead of computing them on the fly to speed up the computation later.
#the alignment is a search problem of complexity len(virtuoso)*len(maestro) and the midi import take some time,
#so better to do it just once for all the pieces.
#As a negative side, this will take a huge amount of memory, so other solutions can be maybe found
# virtuoso_df["norm_notes"]= virtuoso_df.apply(lambda row:  path2normmidinotes(VIRTUOSO_BPATH,row["performed_midi_path"]),axis=1)
# maestro_df["norm_notes"]= maestro_df.apply(lambda row:  path2normmidinotes(MAESTRO_BPATH,row["midi_filename"]),axis=1)

# %%
def notes_are_similar(notes1,notes2, number_to_match,tolerance = 0.03, verbose=False):
    """
    function to test if 2 lists of notes are similar. A note is a triple (start,end,pitch)
    PARAMETERS:
    -number to match: the number of notes (at beginning) to match to consider similar 2 list of notes
    -tolerance: absolute tolerance in ms to consider two time similar
    """
    #test the lenght is number_to_match is not specified
    if number_to_match is None and (len(notes1)!=len(notes2)):
        if verbose: print("Not equal lenght:", len(notes1), "vs", len(notes2))
        return False
    
    onsets1 = [n[0] for n in notes1]
    offsets1 = [n[1] for n in notes1]
    pitches1 = [n[2] for n in notes1]
    onsets2 = [n[0] for n in notes2]
    offsets2 = [n[1] for n in notes2]
    pitches2 = [n[2] for n in notes2]
    #test onsets
    try:
        np.testing.assert_allclose(np.array(onsets1[:number_to_match]), np.array(onsets2[:number_to_match]),atol=tolerance)
    except AssertionError as e:
        if verbose: print("Onset problem:",e)
        return False
    #test offsets
    try:
        np.testing.assert_allclose(np.array(offsets1[:number_to_match]), np.array(offsets2[:number_to_match]),atol=tolerance)
    except AssertionError as e:
        if verbose: print("Offset problem:",e)
        return False
    #test pitches
    if pitches1[:number_to_match] == pitches2[:number_to_match]:
        return True
    else:
        if verbose: 
            print("Pitch problem occurring at indices:")
            print([(i,p1,p2) for i,(p1,p2) in enumerate(zip(pitches1,pitches2)) if p1!=p2])
        return False

def find_similar_midi(df1,df2, number_to_match):
    """
    Given two dataframes find a correspondence of each piece of the first to the second (if exist).
    There is no control for injectivity or uniqueness of the matching function for now except one print warning for multiple matching (that we woul very like to avoid).
    """
    #initialize the line contatining the matching information
    correspondence = []
    #now search for a similar midi in maestro_dict
    for i1,row1 in df1.iterrows():
        #compare row1 with each element of df2
        matched = df2.apply(lambda row2: notes_are_similar(row1["norm_notes"],row2["norm_notes"],5),axis=1)
        #save the matching information
        number_matched = sum(matched)
        if number_matched == 0:
            correspondence.append(None)
        elif number_matched == 1:
            correspondence.append(df2[matched]["midi_filename"].tolist()[0])
        else: #multiple matching 
            print("WARNING: Multiple matching found for", row1["performed_midi_path"])
            correspondence.append(df2[matched]["midi_filename"].tolist())
    df1["correspondence"] =correspondence

# %% [markdown]
# # Let's run it for the Bach

# %%
bach_virtuoso_df = virtuoso_df[virtuoso_df["author"]=="Bach"].copy()
bach_maestro_df = maestro_df[maestro_df["canonical_composer"]=="Johann Sebastian Bach"].copy()

#add the normalized notes
bach_virtuoso_df["norm_notes"]= bach_virtuoso_df.apply(lambda row:  path2normmidinotes(VIRTUOSO_BPATH,row["performed_midi_path"]),axis=1)
bach_maestro_df["norm_notes"]= bach_maestro_df.apply(lambda row:  path2normmidinotes(MAESTRO_BPATH,row["midi_filename"]),axis=1)

# #perform the alignment
find_similar_midi(bach_virtuoso_df,bach_maestro_df, 10)

# %%
temp = bach_virtuoso_df[bach_virtuoso_df["correspondence"].notna()]
temp[[t.split("_")[0]!="Prelude" for t in temp["title"]]]

# We have found mostly preludes (as expected because the fugues are in the same file as preludes in maestro), 
# but also 2 Fugues. Good.

#Let's put those two in the list of correct MIDI 
#format : (virtuosomidi,maestromidi,folder,beginning,end)
# beginning and end are None if we can keep the originals from the file
midi_to_save = []
for i, row in temp[[t.split("_")[0]!="Prelude" for t in temp["title"]]].iterrows():
    midi_to_save.append((row["performed_midi_path"],row["correspondence"],row["folder"],None,None))

# %%
midi_to_save
# Out:
# [('Bach/Fugue/bwv_857/Lan01.mid',
#   '2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_09_Track09_wav.midi',
#   'Bach/Fugue/bwv_857',
#   None,
#   None),
#  ('Bach/Fugue/bwv_874/Kurz01.mid',
#   '2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_03_Track03_wav.midi',
#   'Bach/Fugue/bwv_874',
#   None,
#   None)]

# %% [markdown]
# ## Divide Preludes from fugues

# %%
#consider only the preludes
prelude_virtuoso_df = temp[[t.split("_")[0]=="Prelude" for t in temp["title"]]].copy()
prelude_virtuoso_df
# Out:
#     author                folder  \
# 88    Bach  Bach/Prelude/bwv_846
# 89    Bach  Bach/Prelude/bwv_848
# 90    Bach  Bach/Prelude/bwv_848
# 91    Bach  Bach/Prelude/bwv_848
# 92    Bach  Bach/Prelude/bwv_848
# 93    Bach  Bach/Prelude/bwv_848
# 94    Bach  Bach/Prelude/bwv_848
# 95    Bach  Bach/Prelude/bwv_848
# 96    Bach  Bach/Prelude/bwv_848
# 97    Bach  Bach/Prelude/bwv_848
# 98    Bach  Bach/Prelude/bwv_854
# 99    Bach  Bach/Prelude/bwv_854
# 100   Bach  Bach/Prelude/bwv_854
# 101   Bach  Bach/Prelude/bwv_854
# 102   Bach  Bach/Prelude/bwv_854
# 103   Bach  Bach/Prelude/bwv_856
# 104   Bach  Bach/Prelude/bwv_857
# 105   Bach  Bach/Prelude/bwv_857
# 106   Bach  Bach/Prelude/bwv_857
# 107   Bach  Bach/Prelude/bwv_857
# 108   Bach  Bach/Prelude/bwv_857
# 109   Bach  Bach/Prelude/bwv_857
# 110   Bach  Bach/Prelude/bwv_858
# 111   Bach  Bach/Prelude/bwv_858
# 112   Bach  Bach/Prelude/bwv_860
# 113   Bach  Bach/Prelude/bwv_860
# 114   Bach  Bach/Prelude/bwv_860
# 115   Bach  Bach/Prelude/bwv_860
# 116   Bach  Bach/Prelude/bwv_860
# 117   Bach  Bach/Prelude/bwv_860
# ..     ...                   ...
# 138   Bach  Bach/Prelude/bwv_875
# 139   Bach  Bach/Prelude/bwv_875
# 140   Bach  Bach/Prelude/bwv_875
# 141   Bach  Bach/Prelude/bwv_876
# 142   Bach  Bach/Prelude/bwv_876
# 143   Bach  Bach/Prelude/bwv_880
# 145   Bach  Bach/Prelude/bwv_880
# 146   Bach  Bach/Prelude/bwv_883
# 149   Bach  Bach/Prelude/bwv_883
# 150   Bach  Bach/Prelude/bwv_884
# 151   Bach  Bach/Prelude/bwv_885
# 152   Bach  Bach/Prelude/bwv_885
# 153   Bach  Bach/Prelude/bwv_885
# 154   Bach  Bach/Prelude/bwv_885
# 156   Bach  Bach/Prelude/bwv_885
# 157   Bach  Bach/Prelude/bwv_887
# 158   Bach  Bach/Prelude/bwv_888
# 159   Bach  Bach/Prelude/bwv_889
# 160   Bach  Bach/Prelude/bwv_889
# 161   Bach  Bach/Prelude/bwv_889
# 162   Bach  Bach/Prelude/bwv_889
# 163   Bach  Bach/Prelude/bwv_889
# 164   Bach  Bach/Prelude/bwv_889
# 165   Bach  Bach/Prelude/bwv_891
# 166   Bach  Bach/Prelude/bwv_891
# 167   Bach  Bach/Prelude/bwv_892
# 168   Bach  Bach/Prelude/bwv_892
# 169   Bach  Bach/Prelude/bwv_893
# 170   Bach  Bach/Prelude/bwv_893
# 171   Bach  Bach/Prelude/bwv_893
#
#                               midi2midi_alignment_path  \
# 88        Bach/Prelude/bwv_846/Shi05_infer_corresp.txt
# 89   Bach/Prelude/bwv_848/Denisova06_infer_corresp.txt
# 90        Bach/Prelude/bwv_848/Lee01_infer_corresp.txt
# 91      Bach/Prelude/bwv_848/LeeSH01_infer_corresp.txt
# 92        Bach/Prelude/bwv_848/Lin04_infer_corresp.txt
# 93        Bach/Prelude/bwv_848/Lou01_infer_corresp.txt
# 94   Bach/Prelude/bwv_848/MiyashitaM01_infer_corres...
# 95   Bach/Prelude/bwv_848/Mizumoto03_infer_corresp.txt
# 96       Bach/Prelude/bwv_848/SunY01_infer_corresp.txt
# 97       Bach/Prelude/bwv_848/Zhou01_infer_corresp.txt
# 98        Bach/Prelude/bwv_854/LuA01_infer_corresp.txt
# 99   Bach/Prelude/bwv_854/MiyashitaM01_infer_corres...
# 100     Bach/Prelude/bwv_854/Ozaki01_infer_corresp.txt
# 101  Bach/Prelude/bwv_854/Richardson01_infer_corres...
# 102     Bach/Prelude/bwv_854/WangA01_infer_corresp.txt
# 103      Bach/Prelude/bwv_856/LuoJ01_infer_corresp.txt
# 104  Bach/Prelude/bwv_857/Bult-ItoS02_infer_corresp...
# 105       Bach/Prelude/bwv_857/Lan01_infer_corresp.txt
# 106  Bach/Prelude/bwv_857/Lisiecki04_infer_corresp.txt
# 107       Bach/Prelude/bwv_857/ToA01_infer_corresp.txt
# 108     Bach/Prelude/bwv_857/WangA01_infer_corresp.txt
# 109       Bach/Prelude/bwv_857/YuP01_infer_corresp.txt
# 110       Bach/Prelude/bwv_858/VuV01_infer_corresp.txt
# 111     Bach/Prelude/bwv_858/Zhang01_infer_corresp.txt
# 112        Bach/Prelude/bwv_860/Ko04_infer_corresp.txt
# 113  Bach/Prelude/bwv_860/Nikiforov05_infer_corresp...
# 114  Bach/Prelude/bwv_860/Tetzloff04_infer_corresp.txt
# 115     Bach/Prelude/bwv_860/TuanS01_infer_corresp.txt
# 116    Bach/Prelude/bwv_860/YoungS01_infer_corresp.txt
# 117    Bach/Prelude/bwv_860/ZhangH04_infer_corresp.txt
# ..                                                 ...
# 138     Bach/Prelude/bwv_875/Ahfat01_infer_corresp.txt
# 139      Bach/Prelude/bwv_875/CaoJ01_infer_corresp.txt
# 140      Bach/Prelude/bwv_875/HONG04_infer_corresp.txt
# 141    Bach/Prelude/bwv_876/SirajA01_infer_corresp.txt
# 142      Bach/Prelude/bwv_876/Song01_infer_corresp.txt
# 143    Bach/Prelude/bwv_880/LeungR01_infer_corresp.txt
# 145     Bach/Prelude/bwv_880/WangA04_infer_corresp.txt
# 146      Bach/Prelude/bwv_883/GuoE01_infer_corresp.txt
# 149       Bach/Prelude/bwv_883/LuM01_infer_corresp.txt
# 150       Bach/Prelude/bwv_884/LiA01_infer_corresp.txt
# 151      Bach/Prelude/bwv_885/Chon02_infer_corresp.txt
# 152       Bach/Prelude/bwv_885/Guo01_infer_corresp.txt
# 153     Bach/Prelude/bwv_885/Huang04_infer_corresp.txt
# 154     Bach/Prelude/bwv_885/JeonH01_infer_corresp.txt
# 156    Bach/Prelude/bwv_885/SINKEV06_infer_corresp.txt
# 157      Bach/Prelude/bwv_887/LiYZ01_infer_corresp.txt
# 158     Bach/Prelude/bwv_888/ZhaoK01_infer_corresp.txt
# 159  Bach/Prelude/bwv_889/Giesbrecht01_infer_corres...
# 160      Bach/Prelude/bwv_889/LiuY01_infer_corresp.txt
# 161      Bach/Prelude/bwv_889/MunA01_infer_corresp.txt
# 162      Bach/Prelude/bwv_889/Wang01_infer_corresp.txt
# 163     Bach/Prelude/bwv_889/YangY02_infer_corresp.txt
# 164    Bach/Prelude/bwv_889/ZhangW02_infer_corresp.txt
# 165    Bach/Prelude/bwv_891/BLINOV04_infer_corresp.txt
# 166   Bach/Prelude/bwv_891/Duepree06_infer_corresp.txt
# 167       Bach/Prelude/bwv_892/Hou01_infer_corresp.txt
# 168   Bach/Prelude/bwv_892/KabuliL01_infer_corresp.txt
# 169   Bach/Prelude/bwv_893/Kleisen04_infer_corresp.txt
# 170  Bach/Prelude/bwv_893/Levitsky04_infer_corresp.txt
# 171      Bach/Prelude/bwv_893/Wong01_infer_corresp.txt
#
#                        performed_midi_path     performer  \
# 88          Bach/Prelude/bwv_846/Shi05.mid         Shi05
# 89     Bach/Prelude/bwv_848/Denisova06.mid    Denisova06
# 90          Bach/Prelude/bwv_848/Lee01.mid         Lee01
# 91        Bach/Prelude/bwv_848/LeeSH01.mid       LeeSH01
# 92          Bach/Prelude/bwv_848/Lin04.mid         Lin04
# 93          Bach/Prelude/bwv_848/Lou01.mid         Lou01
# 94   Bach/Prelude/bwv_848/MiyashitaM01.mid  MiyashitaM01
# 95     Bach/Prelude/bwv_848/Mizumoto03.mid    Mizumoto03
# 96         Bach/Prelude/bwv_848/SunY01.mid        SunY01
# 97         Bach/Prelude/bwv_848/Zhou01.mid        Zhou01
# 98          Bach/Prelude/bwv_854/LuA01.mid         LuA01
# 99   Bach/Prelude/bwv_854/MiyashitaM01.mid  MiyashitaM01
# 100       Bach/Prelude/bwv_854/Ozaki01.mid       Ozaki01
# 101  Bach/Prelude/bwv_854/Richardson01.mid  Richardson01
# 102       Bach/Prelude/bwv_854/WangA01.mid       WangA01
# 103        Bach/Prelude/bwv_856/LuoJ01.mid        LuoJ01
# 104   Bach/Prelude/bwv_857/Bult-ItoS02.mid   Bult-ItoS02
# 105         Bach/Prelude/bwv_857/Lan01.mid         Lan01
# 106    Bach/Prelude/bwv_857/Lisiecki04.mid    Lisiecki04
# 107         Bach/Prelude/bwv_857/ToA01.mid         ToA01
# 108       Bach/Prelude/bwv_857/WangA01.mid       WangA01
# 109         Bach/Prelude/bwv_857/YuP01.mid         YuP01
# 110         Bach/Prelude/bwv_858/VuV01.mid         VuV01
# 111       Bach/Prelude/bwv_858/Zhang01.mid       Zhang01
# 112          Bach/Prelude/bwv_860/Ko04.mid          Ko04
# 113   Bach/Prelude/bwv_860/Nikiforov05.mid   Nikiforov05
# 114    Bach/Prelude/bwv_860/Tetzloff04.mid    Tetzloff04
# 115       Bach/Prelude/bwv_860/TuanS01.mid       TuanS01
# 116      Bach/Prelude/bwv_860/YoungS01.mid      YoungS01
# 117      Bach/Prelude/bwv_860/ZhangH04.mid      ZhangH04
# ..                                     ...           ...
# 138       Bach/Prelude/bwv_875/Ahfat01.mid       Ahfat01
# 139        Bach/Prelude/bwv_875/CaoJ01.mid        CaoJ01
# 140        Bach/Prelude/bwv_875/HONG04.mid        HONG04
# 141      Bach/Prelude/bwv_876/SirajA01.mid      SirajA01
# 142        Bach/Prelude/bwv_876/Song01.mid        Song01
# 143      Bach/Prelude/bwv_880/LeungR01.mid      LeungR01
# 145       Bach/Prelude/bwv_880/WangA04.mid       WangA04
# 146        Bach/Prelude/bwv_883/GuoE01.mid        GuoE01
# 149         Bach/Prelude/bwv_883/LuM01.mid         LuM01
# 150         Bach/Prelude/bwv_884/LiA01.mid         LiA01
# 151        Bach/Prelude/bwv_885/Chon02.mid        Chon02
# 152         Bach/Prelude/bwv_885/Guo01.mid         Guo01
# 153       Bach/Prelude/bwv_885/Huang04.mid       Huang04
# 154       Bach/Prelude/bwv_885/JeonH01.mid       JeonH01
# 156      Bach/Prelude/bwv_885/SINKEV06.mid      SINKEV06
# 157        Bach/Prelude/bwv_887/LiYZ01.mid        LiYZ01
# 158       Bach/Prelude/bwv_888/ZhaoK01.mid       ZhaoK01
# 159  Bach/Prelude/bwv_889/Giesbrecht01.mid  Giesbrecht01
# 160        Bach/Prelude/bwv_889/LiuY01.mid        LiuY01
# 161        Bach/Prelude/bwv_889/MunA01.mid        MunA01
# 162        Bach/Prelude/bwv_889/Wang01.mid        Wang01
# 163       Bach/Prelude/bwv_889/YangY02.mid       YangY02
# 164      Bach/Prelude/bwv_889/ZhangW02.mid      ZhangW02
# 165      Bach/Prelude/bwv_891/BLINOV04.mid      BLINOV04
# 166     Bach/Prelude/bwv_891/Duepree06.mid     Duepree06
# 167         Bach/Prelude/bwv_892/Hou01.mid         Hou01
# 168     Bach/Prelude/bwv_892/KabuliL01.mid     KabuliL01
# 169     Bach/Prelude/bwv_893/Kleisen04.mid     Kleisen04
# 170    Bach/Prelude/bwv_893/Levitsky04.mid    Levitsky04
# 171        Bach/Prelude/bwv_893/Wong01.mid        Wong01
#
#                                   score2midi_alignment  \
# 88          Bach/Prelude/bwv_846/Shi05_infer_match.txt
# 89     Bach/Prelude/bwv_848/Denisova06_infer_match.txt
# 90          Bach/Prelude/bwv_848/Lee01_infer_match.txt
# 91        Bach/Prelude/bwv_848/LeeSH01_infer_match.txt
# 92          Bach/Prelude/bwv_848/Lin04_infer_match.txt
# 93          Bach/Prelude/bwv_848/Lou01_infer_match.txt
# 94   Bach/Prelude/bwv_848/MiyashitaM01_infer_match.txt
# 95     Bach/Prelude/bwv_848/Mizumoto03_infer_match.txt
# 96         Bach/Prelude/bwv_848/SunY01_infer_match.txt
# 97         Bach/Prelude/bwv_848/Zhou01_infer_match.txt
# 98          Bach/Prelude/bwv_854/LuA01_infer_match.txt
# 99   Bach/Prelude/bwv_854/MiyashitaM01_infer_match.txt
# 100       Bach/Prelude/bwv_854/Ozaki01_infer_match.txt
# 101  Bach/Prelude/bwv_854/Richardson01_infer_match.txt
# 102       Bach/Prelude/bwv_854/WangA01_infer_match.txt
# 103        Bach/Prelude/bwv_856/LuoJ01_infer_match.txt
# 104   Bach/Prelude/bwv_857/Bult-ItoS02_infer_match.txt
# 105         Bach/Prelude/bwv_857/Lan01_infer_match.txt
# 106    Bach/Prelude/bwv_857/Lisiecki04_infer_match.txt
# 107         Bach/Prelude/bwv_857/ToA01_infer_match.txt
# 108       Bach/Prelude/bwv_857/WangA01_infer_match.txt
# 109         Bach/Prelude/bwv_857/YuP01_infer_match.txt
# 110         Bach/Prelude/bwv_858/VuV01_infer_match.txt
# 111       Bach/Prelude/bwv_858/Zhang01_infer_match.txt
# 112          Bach/Prelude/bwv_860/Ko04_infer_match.txt
# 113   Bach/Prelude/bwv_860/Nikiforov05_infer_match.txt
# 114    Bach/Prelude/bwv_860/Tetzloff04_infer_match.txt
# 115       Bach/Prelude/bwv_860/TuanS01_infer_match.txt
# 116      Bach/Prelude/bwv_860/YoungS01_infer_match.txt
# 117      Bach/Prelude/bwv_860/ZhangH04_infer_match.txt
# ..                                                 ...
# 138       Bach/Prelude/bwv_875/Ahfat01_infer_match.txt
# 139        Bach/Prelude/bwv_875/CaoJ01_infer_match.txt
# 140        Bach/Prelude/bwv_875/HONG04_infer_match.txt
# 141      Bach/Prelude/bwv_876/SirajA01_infer_match.txt
# 142        Bach/Prelude/bwv_876/Song01_infer_match.txt
# 143      Bach/Prelude/bwv_880/LeungR01_infer_match.txt
# 145       Bach/Prelude/bwv_880/WangA04_infer_match.txt
# 146        Bach/Prelude/bwv_883/GuoE01_infer_match.txt
# 149         Bach/Prelude/bwv_883/LuM01_infer_match.txt
# 150         Bach/Prelude/bwv_884/LiA01_infer_match.txt
# 151        Bach/Prelude/bwv_885/Chon02_infer_match.txt
# 152         Bach/Prelude/bwv_885/Guo01_infer_match.txt
# 153       Bach/Prelude/bwv_885/Huang04_infer_match.txt
# 154       Bach/Prelude/bwv_885/JeonH01_infer_match.txt
# 156      Bach/Prelude/bwv_885/SINKEV06_infer_match.txt
# 157        Bach/Prelude/bwv_887/LiYZ01_infer_match.txt
# 158       Bach/Prelude/bwv_888/ZhaoK01_infer_match.txt
# 159  Bach/Prelude/bwv_889/Giesbrecht01_infer_match.txt
# 160        Bach/Prelude/bwv_889/LiuY01_infer_match.txt
# 161        Bach/Prelude/bwv_889/MunA01_infer_match.txt
# 162        Bach/Prelude/bwv_889/Wang01_infer_match.txt
# 163       Bach/Prelude/bwv_889/YangY02_infer_match.txt
# 164      Bach/Prelude/bwv_889/ZhangW02_infer_match.txt
# 165      Bach/Prelude/bwv_891/BLINOV04_infer_match.txt
# 166     Bach/Prelude/bwv_891/Duepree06_infer_match.txt
# 167         Bach/Prelude/bwv_892/Hou01_infer_match.txt
# 168     Bach/Prelude/bwv_892/KabuliL01_infer_match.txt
# 169     Bach/Prelude/bwv_893/Kleisen04_infer_match.txt
# 170    Bach/Prelude/bwv_893/Levitsky04_infer_match.txt
# 171        Bach/Prelude/bwv_893/Wong01_infer_match.txt
#
#                            score_midi_path  \
# 88   Bach/Prelude/bwv_846/midi_cleaned.mid
# 89   Bach/Prelude/bwv_848/midi_cleaned.mid
# 90   Bach/Prelude/bwv_848/midi_cleaned.mid
# 91   Bach/Prelude/bwv_848/midi_cleaned.mid
# 92   Bach/Prelude/bwv_848/midi_cleaned.mid
# 93   Bach/Prelude/bwv_848/midi_cleaned.mid
# 94   Bach/Prelude/bwv_848/midi_cleaned.mid
# 95   Bach/Prelude/bwv_848/midi_cleaned.mid
# 96   Bach/Prelude/bwv_848/midi_cleaned.mid
# 97   Bach/Prelude/bwv_848/midi_cleaned.mid
# 98   Bach/Prelude/bwv_854/midi_cleaned.mid
# 99   Bach/Prelude/bwv_854/midi_cleaned.mid
# 100  Bach/Prelude/bwv_854/midi_cleaned.mid
# 101  Bach/Prelude/bwv_854/midi_cleaned.mid
# 102  Bach/Prelude/bwv_854/midi_cleaned.mid
# 103  Bach/Prelude/bwv_856/midi_cleaned.mid
# 104  Bach/Prelude/bwv_857/midi_cleaned.mid
# 105  Bach/Prelude/bwv_857/midi_cleaned.mid
# 106  Bach/Prelude/bwv_857/midi_cleaned.mid
# 107  Bach/Prelude/bwv_857/midi_cleaned.mid
# 108  Bach/Prelude/bwv_857/midi_cleaned.mid
# 109  Bach/Prelude/bwv_857/midi_cleaned.mid
# 110  Bach/Prelude/bwv_858/midi_cleaned.mid
# 111  Bach/Prelude/bwv_858/midi_cleaned.mid
# 112  Bach/Prelude/bwv_860/midi_cleaned.mid
# 113  Bach/Prelude/bwv_860/midi_cleaned.mid
# 114  Bach/Prelude/bwv_860/midi_cleaned.mid
# 115  Bach/Prelude/bwv_860/midi_cleaned.mid
# 116  Bach/Prelude/bwv_860/midi_cleaned.mid
# 117  Bach/Prelude/bwv_860/midi_cleaned.mid
# ..                                     ...
# 138  Bach/Prelude/bwv_875/midi_cleaned.mid
# 139  Bach/Prelude/bwv_875/midi_cleaned.mid
# 140  Bach/Prelude/bwv_875/midi_cleaned.mid
# 141  Bach/Prelude/bwv_876/midi_cleaned.mid
# 142  Bach/Prelude/bwv_876/midi_cleaned.mid
# 143  Bach/Prelude/bwv_880/midi_cleaned.mid
# 145  Bach/Prelude/bwv_880/midi_cleaned.mid
# 146  Bach/Prelude/bwv_883/midi_cleaned.mid
# 149  Bach/Prelude/bwv_883/midi_cleaned.mid
# 150  Bach/Prelude/bwv_884/midi_cleaned.mid
# 151  Bach/Prelude/bwv_885/midi_cleaned.mid
# 152  Bach/Prelude/bwv_885/midi_cleaned.mid
# 153  Bach/Prelude/bwv_885/midi_cleaned.mid
# 154  Bach/Prelude/bwv_885/midi_cleaned.mid
# 156  Bach/Prelude/bwv_885/midi_cleaned.mid
# 157  Bach/Prelude/bwv_887/midi_cleaned.mid
# 158  Bach/Prelude/bwv_888/midi_cleaned.mid
# 159  Bach/Prelude/bwv_889/midi_cleaned.mid
# 160  Bach/Prelude/bwv_889/midi_cleaned.mid
# 161  Bach/Prelude/bwv_889/midi_cleaned.mid
# 162  Bach/Prelude/bwv_889/midi_cleaned.mid
# 163  Bach/Prelude/bwv_889/midi_cleaned.mid
# 164  Bach/Prelude/bwv_889/midi_cleaned.mid
# 165  Bach/Prelude/bwv_891/midi_cleaned.mid
# 166  Bach/Prelude/bwv_891/midi_cleaned.mid
# 167  Bach/Prelude/bwv_892/midi_cleaned.mid
# 168  Bach/Prelude/bwv_892/midi_cleaned.mid
# 169  Bach/Prelude/bwv_893/midi_cleaned.mid
# 170  Bach/Prelude/bwv_893/midi_cleaned.mid
# 171  Bach/Prelude/bwv_893/midi_cleaned.mid
#
#                                      score_xml_path            title  \
# 88   Bach/Prelude/bwv_846/musicxml_cleaned.musicxml  Prelude_bwv_846
# 89   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 90   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 91   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 92   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 93   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 94   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 95   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 96   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 97   Bach/Prelude/bwv_848/musicxml_cleaned.musicxml  Prelude_bwv_848
# 98   Bach/Prelude/bwv_854/musicxml_cleaned.musicxml  Prelude_bwv_854
# 99   Bach/Prelude/bwv_854/musicxml_cleaned.musicxml  Prelude_bwv_854
# 100  Bach/Prelude/bwv_854/musicxml_cleaned.musicxml  Prelude_bwv_854
# 101  Bach/Prelude/bwv_854/musicxml_cleaned.musicxml  Prelude_bwv_854
# 102  Bach/Prelude/bwv_854/musicxml_cleaned.musicxml  Prelude_bwv_854
# 103  Bach/Prelude/bwv_856/musicxml_cleaned.musicxml  Prelude_bwv_856
# 104  Bach/Prelude/bwv_857/musicxml_cleaned.musicxml  Prelude_bwv_857
# 105  Bach/Prelude/bwv_857/musicxml_cleaned.musicxml  Prelude_bwv_857
# 106  Bach/Prelude/bwv_857/musicxml_cleaned.musicxml  Prelude_bwv_857
# 107  Bach/Prelude/bwv_857/musicxml_cleaned.musicxml  Prelude_bwv_857
# 108  Bach/Prelude/bwv_857/musicxml_cleaned.musicxml  Prelude_bwv_857
# 109  Bach/Prelude/bwv_857/musicxml_cleaned.musicxml  Prelude_bwv_857
# 110  Bach/Prelude/bwv_858/musicxml_cleaned.musicxml  Prelude_bwv_858
# 111  Bach/Prelude/bwv_858/musicxml_cleaned.musicxml  Prelude_bwv_858
# 112  Bach/Prelude/bwv_860/musicxml_cleaned.musicxml  Prelude_bwv_860
# 113  Bach/Prelude/bwv_860/musicxml_cleaned.musicxml  Prelude_bwv_860
# 114  Bach/Prelude/bwv_860/musicxml_cleaned.musicxml  Prelude_bwv_860
# 115  Bach/Prelude/bwv_860/musicxml_cleaned.musicxml  Prelude_bwv_860
# 116  Bach/Prelude/bwv_860/musicxml_cleaned.musicxml  Prelude_bwv_860
# 117  Bach/Prelude/bwv_860/musicxml_cleaned.musicxml  Prelude_bwv_860
# ..                                              ...              ...
# 138  Bach/Prelude/bwv_875/musicxml_cleaned.musicxml  Prelude_bwv_875
# 139  Bach/Prelude/bwv_875/musicxml_cleaned.musicxml  Prelude_bwv_875
# 140  Bach/Prelude/bwv_875/musicxml_cleaned.musicxml  Prelude_bwv_875
# 141  Bach/Prelude/bwv_876/musicxml_cleaned.musicxml  Prelude_bwv_876
# 142  Bach/Prelude/bwv_876/musicxml_cleaned.musicxml  Prelude_bwv_876
# 143  Bach/Prelude/bwv_880/musicxml_cleaned.musicxml  Prelude_bwv_880
# 145  Bach/Prelude/bwv_880/musicxml_cleaned.musicxml  Prelude_bwv_880
# 146  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883
# 149  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883
# 150  Bach/Prelude/bwv_884/musicxml_cleaned.musicxml  Prelude_bwv_884
# 151  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 152  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 153  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 154  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 156  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 157  Bach/Prelude/bwv_887/musicxml_cleaned.musicxml  Prelude_bwv_887
# 158  Bach/Prelude/bwv_888/musicxml_cleaned.musicxml  Prelude_bwv_888
# 159  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 160  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 161  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 162  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 163  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 164  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 165  Bach/Prelude/bwv_891/musicxml_cleaned.musicxml  Prelude_bwv_891
# 166  Bach/Prelude/bwv_891/musicxml_cleaned.musicxml  Prelude_bwv_891
# 167  Bach/Prelude/bwv_892/musicxml_cleaned.musicxml  Prelude_bwv_892
# 168  Bach/Prelude/bwv_892/musicxml_cleaned.musicxml  Prelude_bwv_892
# 169  Bach/Prelude/bwv_893/musicxml_cleaned.musicxml  Prelude_bwv_893
# 170  Bach/Prelude/bwv_893/musicxml_cleaned.musicxml  Prelude_bwv_893
# 171  Bach/Prelude/bwv_893/musicxml_cleaned.musicxml  Prelude_bwv_893
#
#                                             norm_notes  \
# 88   [(0.0, 0.9177359145833337, 60), (0.22863269583...
# 89   [(0.0, 0.2126070395833335, 49), (0.00106837708...
# 90   [(0.0, 0.46688078541666667, 49), (0.0074786395...
# 91   [(0.0, 0.13888902083333332, 77), (0.0138889020...
# 92   [(0.0, 0.13888902083333332, 77), (0.0032051312...
# 93   [(0.0, 0.12606849583333335, 77), (0.0074786395...
# 94   [(0.0, 0.09281249999999996, 77), (0.0165625000...
# 95   [(0.0, 0.10683770833333339, 77), (0.0288461812...
# 96   [(0.0, 0.07478639583333335, 77), (0.0096153937...
# 97   [(0.0, 0.46581240833333337, 49), (0.0106837708...
# 98   [(0.0, 6.4281250000000005, 52), (0.04374999999...
# 99   [(0.0, 5.4679539125000005, 52), (0.00641026249...
# 100  [(0.0, 6.180561427083334, 52), (0.005341885416...
# 101  [(0.0, 0.6047014291666668, 64), (0.00534188541...
# 102  [(0.0, 5.47756930625, 52), (0.0053418854166665...
# 103  [(0.0, 0.06374999999999997, 53), (0.0137500000...
# 104  [(0.0, 0.9896875, 65), (0.03125, 1.3875, 56), ...
# 105  [(0.0, 1.0758557229166668, 65), (0.00854701666...
# 106  [(0.0, 1.59936049375, 65), (0.0309829354166666...
# 107  [(0.0, 1.8910274375, 56), (0.00961539374999997...
# 108  [(0.0, 1.5749999999999997, 56), (0.00218750000...
# 109  [(0.0, 1.0523514270833334, 65), (0.00854701666...
# 110  [(0.0, 0.385625, 66), (0.23875000000000002, 0....
# 111  [(0.0, 0.27243615625000006, 66), (0.2403848437...
# 112  [(0.0, 0.07371801874999995, 67), (0.0042735083...
# 113  [(0.0, 0.10470095416666658, 67), (0.0267094270...
# 114  [(0.0, 0.36324820833333327, 55), (0.0042735083...
# 115  [(0.0, 0.04166670625000002, 55), (0.0074786395...
# 116  [(0.0, 0.07281250000000006, 67), (0.0218749999...
# 117  [(0.0, 0.11965823333333336, 67), (0.0085470166...
# ..                                                 ...
# 138  [(0.0, 0.06837613333333337, 50), (0.0117521479...
# 139  [(0.0, 0.05448723124999999, 50), (0.0256410499...
# 140  [(0.0, 0.3183763708333336, 74), (0.00641026250...
# 141  [(0.0, 0.9305564395833333, 70), (0.00854701666...
# 142  [(0.0, 0.884616225, 70), (0.008547016666666685...
# 143  [(0.0, 1.0555565583333335, 41), (0.27457291041...
# 145  [(0.0, 0.7425220729166666, 41), (0.19551300625...
# 146  [(0.0, 0.9081205208333334, 78), (0.01175214791...
# 149  [(0.0, 0.37187499999999996, 78), (0.0365624999...
# 150  [(0.0, 0.24679510625, 59), (0.0128205249999999...
# 151  [(0.0, 7.200861541666668, 43), (0.980770162500...
# 152  [(0.0, 6.913468106250001, 43), (0.880342716666...
# 153  [(0.0, 6.320518825000001, 43), (0.809829829166...
# 154  [(0.0, 8.32375, 43), (1.0009375, 1.3071875, 67...
# 156  [(0.0, 6.635690064583334, 43), (0.840812764583...
# 157  [(0.0, 0.1428125, 68), (0.008437499999999987, ...
# 158  [(0.0, 1.3218750000000001, 64), (0.01156250000...
# 159  [(0.0, 0.28418830416666674, 45), (0.1666668250...
# 160  [(0.0, 0.58653901875, 45), (0.1517095458333333...
# 161  [(0.0, 0.51875, 45), (0.11656250000000001, 0.2...
# 162  [(0.0, 0.6602570375000001, 45), (0.13888902083...
# 163  [(0.0, 0.1559830541666667, 45), (0.15064116875...
# 164  [(0.0, 0.9017102583333333, 45), (0.13141038125...
# 165  [(0.0, 0.7029921208333336, 73), (0.01068377083...
# 166  [(0.0, 0.2991455833333334, 73), (0.01602565625...
# 167  [(0.0, 0.5117526229166667, 47), (0.15064116875...
# 168  [(0.0, 0.5202996395833335, 47), (0.14209415208...
# 169  [(0.0, 0.2980772062500001, 62), (0.01495727916...
# 170  [(0.0, 0.33012851875000004, 62), (0.0128205249...
# 171  [(0.0, 0.3376071583333333, 62), (0.00534188541...
#
#                                         correspondence
# 88   2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MI...
# 89   2008/MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MI...
# 90   2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1...
# 91   2017/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-...
# 92   2008/MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MI...
# 93   2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1...
# 94   2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-fr...
# 95   2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1...
# 96   2017/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-...
# 97   2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1...
# 98   2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 99   2017/MIDI-Unprocessed_051_PIANO051_MID--AUDIO-...
# 100  2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1...
# 101  2013/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_...
# 102  2017/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-...
# 103  2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 104  2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 105  2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1...
# 106  2008/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MI...
# 107  2017/MIDI-Unprocessed_048_PIANO048_MID--AUDIO-...
# 108  2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-f...
# 109  2017/MIDI-Unprocessed_042_PIANO042_MID--AUDIO-...
# 110  2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 111  2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1...
# 112  2008/MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MI...
# 113  2008/MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MI...
# 114  2008/MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MI...
# 115  2017/MIDI-Unprocessed_057_PIANO057_MID--AUDIO-...
# 116  2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-f...
# 117  2008/MIDI-Unprocessed_18_R1_2008_01-04_ORIG_MI...
# ..                                                 ...
# 138  2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1...
# 139  2017/MIDI-Unprocessed_065_PIANO065_MID--AUDIO-...
# 140  2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG...
# 141  2017/MIDI-Unprocessed_061_PIANO061_MID--AUDIO-...
# 142  2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1...
# 143  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...
# 145  2008/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MI...
# 146  2017/MIDI-Unprocessed_050_PIANO050_MID--AUDIO-...
# 149  2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-fr...
# 150  2017/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-...
# 151  2011/MIDI-Unprocessed_22_R1_2011_MID--AUDIO_R1...
# 152  2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1...
# 153  2008/MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MI...
# 154  2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-f...
# 156  2004/MIDI-Unprocessed_SMF_17_R1_2004_01-02_ORI...
# 157  2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 158  2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-f...
# 159  2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1...
# 160  2017/MIDI-Unprocessed_054_PIANO054_MID--AUDIO-...
# 161  2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-fr...
# 162  2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1...
# 163  2017/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-...
# 164  2017/MIDI-Unprocessed_062_PIANO062_MID--AUDIO-...
# 165  2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG...
# 166  2008/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MI...
# 167  2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1...
# 168  2017/MIDI-Unprocessed_055_PIANO055_MID--AUDIO-...
# 169  2008/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MI...
# 170  2008/MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MI...
# 171  2013/ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_...
#
# [78 rows x 11 columns]

# %%
#add the norm_notes for the aligned maestro performances in prelude_virtuoso_df
prelude_virtuoso_df["maestro_norm_notes"] = prelude_virtuoso_df.apply(lambda row:  path2normmidinotes(MAESTRO_BPATH,row["correspondence"]),axis=1)

# %%
def find_split_point_bach(norm_notes,maestro_norm_notes,tolerance):
    """
    Find the split point between preludes and fugues in the coupled maestro performances
    """
    #some checkings
    if len(maestro_norm_notes) == len(norm_notes): # only prelude
        assert(notes_are_similar(norm_notes,maestro_norm_notes, len(maestro_norm_notes),tolerance=tolerance,verbose= True))
        return np.nan
    #double check there are not strange things happening in the prelude part
    if not notes_are_similar(norm_notes,maestro_norm_notes, len(norm_notes),tolerance=tolerance,verbose = True):
        return 0 # here we use 0 to be able to filter out those weird element later
    change_point = maestro_norm_notes[len(norm_notes)][0]
    return change_point

# %%
prelude_virtuoso_df["split_point"] = prelude_virtuoso_df.apply(lambda row: find_split_point_bach(row["norm_notes"],row["maestro_norm_notes"],0.5),axis = 1)
# Out:
# Onset problem:
# Not equal to tolerance rtol=1e-07, atol=0.5
#
# (shapes (510,), (129,) mismatch)
#  x: array([  0.      ,   0.98077 ,   1.060898,   1.920942,   2.011754,
#          2.863251,   2.96261 ,   3.787397,   3.905987,   4.662398,
#          4.727569,   4.840817,   5.681629,   5.810903,   6.584408,...
#  y: array([ 0.      ,  0.980469,  1.059896,  1.920573,  2.010417,  2.863281,
#         2.96224 ,  3.78776 ,  3.90625 ,  4.661458,  4.727865,  4.841146,
#         5.68099 ,  5.807292,  6.580729,  6.643229,  6.776042,  7.565104,...
# Onset problem:
# Not equal to tolerance rtol=1e-07, atol=0.5
#
# Mismatch: 20.4%
# Max absolute difference: 5.34188794
# Max relative difference: nan
#  x: array([  0.      ,   0.840813,   0.965813,   1.722224,   1.868592,
#          2.627139,   2.773507,   3.530986,   3.69338 ,   4.354705,
#          4.433765,   4.504278,   4.581201,   5.317313,   5.480774,...
#  y: array([  0.      ,   0.841667,   0.966667,   1.728125,   1.875   ,
#          2.633333,   2.779167,   3.5375  ,   3.7     ,   4.360417,
#          4.439583,   4.510417,   4.5875  ,   5.323958,   5.486458,...

# %%
#create a list of pieces of maestro that we don't want to use:
midi_to_not_use = []

#add the 2 pieces where weird things happened (a cut performance during the prelude and one with the onsets very different)
for i, row in prelude_virtuoso_df[prelude_virtuoso_df["split_point"]==0].iterrows():
    midi_to_not_use.append(((row["performed_midi_path"],row["correspondence"],row["folder"])))
    
#add to the midi_to_use the three pieces that are only prelude
for i, row in prelude_virtuoso_df[prelude_virtuoso_df["split_point"].isna()].iterrows():
    midi_to_save.append((row["performed_midi_path"],row["correspondence"],row["folder"],None,None))

# %%
#remove from the dataset the pieces already considered
prelude_virtuoso_df = prelude_virtuoso_df[prelude_virtuoso_df["split_point"]!=0]
prelude_virtuoso_df = prelude_virtuoso_df[prelude_virtuoso_df["split_point"].notna()]

# %% [markdown]
# ## Check the fugues

# %%
#we use the midi file name (folder+performer) changing it to "fugue" to find the correspective fugue from the prelude
fugue_matched_performances_list = [p.replace("Prelude","Fugue") for p in prelude_virtuoso_df["performed_midi_path"]]

fugue_virtuoso_df = bach_virtuoso_df [[p["performed_midi_path"] in fugue_matched_performances_list for i,p in bach_virtuoso_df.iterrows()]]

#drop the correspondence column (that is nan anyway), we will take this information later
fugue_virtuoso_df = fugue_virtuoso_df.drop(["correspondence"],axis = 1)

#add the column "opusperformer" to perform the joining later with preludes
fugue_virtuoso_df["opusperformer"] = [t.split("/")[2]+"/"+t.split("/")[3] for t in fugue_virtuoso_df["performed_midi_path"]]

# %%
#add "opusperformer" also to the prelude to perform the join
temp = prelude_virtuoso_df.copy()
temp["opusperformer"] = [t.split("/")[2]+"/"+t.split("/")[3] for t in prelude_virtuoso_df["performed_midi_path"]]
temp = temp[["opusperformer","split_point","correspondence"]]

# add the splitpoint and correspondence information joining the tables on the midi file name
fugue_virtuoso_df = fugue_virtuoso_df.join(temp.set_index(["opusperformer"]), on=["opusperformer"])

#drop the "opusperformer" row now useless
fugue_virtuoso_df = fugue_virtuoso_df.drop(["opusperformer"],axis = 1)

# %%
#add the norm_notes for the maestro fugues
fugue_virtuoso_df["maestro_norm_notes"]= fugue_virtuoso_df.apply(lambda row: path2normmidinotes(MAESTRO_BPATH,row["correspondence"],start=row["split_point"]),axis=1)

# %%
#check if the norm notes are similar
fugue_virtuoso_df["aligned"] = fugue_virtuoso_df.apply(lambda row: notes_are_similar(row["norm_notes"],row["maestro_norm_notes"], None,tolerance=0.5,verbose=True),axis=1)

# there are some problems, but nothing too problematic because we are going to realign them with nakamura, so we accept them
# Out:
# Pitch problem occurring at indices:
# [(386, 52, 45), (387, 45, 52)]
# Offset problem:
# Not equal to tolerance rtol=1e-07, atol=0.5
#
# Mismatch: 0.209%
# Max absolute difference: 2.53205974
# Max relative difference: 0.01003287
#  x: array([1.153847e-01, 3.087610e-01, 4.615389e-01, ..., 2.547406e+02,
#        2.549084e+02, 2.548421e+02])
#  y: array([1.145833e-01, 3.085937e-01, 4.609375e-01, ..., 2.523763e+02,
#        2.523763e+02, 2.523763e+02])
# Pitch problem occurring at indices:
# [(766, 61, 45), (767, 45, 61)]

# %%
#add to the midi_to_use the preludes
for i, row in prelude_virtuoso_df.iterrows():
    midi_to_save.append((row["performed_midi_path"],row["correspondence"],row["folder"],None,row["norm_notes"][-1][1]))

# %%
#add to the midi_to_use the fugues
for i, row in fugue_virtuoso_df.iterrows():
    midi_to_save.append((row["performed_midi_path"],row["correspondence"],row["folder"],row["split_point"],None))

# %%
len(midi_to_save)
# Out:
# 150

# %%
midi_to_save
# Out:
# [('Bach/Fugue/bwv_857/Lan01.mid',
#   '2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_09_Track09_wav.midi',
#   'Bach/Fugue/bwv_857',
#   None,
#   None),
#  ('Bach/Fugue/bwv_874/Kurz01.mid',
#   '2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_03_Track03_wav.midi',
#   'Bach/Fugue/bwv_874',
#   None,
#   None),
#  ('Bach/Prelude/bwv_857/Lan01.mid',
#   '2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_08_Track08_wav.midi',
#   'Bach/Prelude/bwv_857',
#   None,
#   None),
#  ('Bach/Prelude/bwv_874/BianF01.mid',
#   '2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_02_Track02_wav.midi',
#   'Bach/Prelude/bwv_874',
#   None,
#   None),
#  ('Bach/Prelude/bwv_874/Kurz01.mid',
#   '2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_02_Track02_wav.midi',
#   'Bach/Prelude/bwv_874',
#   None,
#   None),
#  ('Bach/Prelude/bwv_846/Shi05.mid',
#   '2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_01_Track01_wav.midi',
#   'Bach/Prelude/bwv_846',
#   None,
#   136.80248038958334),
#  ('Bach/Prelude/bwv_848/Denisova06.mid',
#   '2008/MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   67.79066269166667),
#  ('Bach/Prelude/bwv_848/Lee01.mid',
#   '2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_07_Track07_wav.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   72.97335992291667),
#  ('Bach/Prelude/bwv_848/LeeSH01.mid',
#   '2017/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--1.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   80.23939246666667),
#  ('Bach/Prelude/bwv_848/Lin04.mid',
#   '2008/MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   71.73511088333333),
#  ('Bach/Prelude/bwv_848/Lou01.mid',
#   '2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_08_Track08_wav.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   70.95840074375),
#  ('Bach/Prelude/bwv_848/MiyashitaM01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_09_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   74.396875),
#  ('Bach/Prelude/bwv_848/Mizumoto03.mid',
#   '2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_15_Track15_wav.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   70.46053702291668),
#  ('Bach/Prelude/bwv_848/SunY01.mid',
#   '2017/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--1.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   64.20091569166668),
#  ('Bach/Prelude/bwv_848/Zhou01.mid',
#   '2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_02_Track02_wav.midi',
#   'Bach/Prelude/bwv_848',
#   None,
#   67.08126030833334),
#  ('Bach/Prelude/bwv_854/LuA01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_854',
#   None,
#   88.84875000000001),
#  ('Bach/Prelude/bwv_854/MiyashitaM01.mid',
#   '2017/MIDI-Unprocessed_051_PIANO051_MID--AUDIO-split_07-06-17_Piano-e_3-02_wav--1.midi',
#   'Bach/Prelude/bwv_854',
#   None,
#   79.3526394875),
#  ('Bach/Prelude/bwv_854/Ozaki01.mid',
#   '2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav.midi',
#   'Bach/Prelude/bwv_854',
#   None,
#   83.77358385833334),
#  ('Bach/Prelude/bwv_854/Richardson01.mid',
#   '2013/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--1.midi',
#   'Bach/Prelude/bwv_854',
#   None,
#   90.95841974375001),
#  ('Bach/Prelude/bwv_854/WangA01.mid',
#   '2017/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--1.midi',
#   'Bach/Prelude/bwv_854',
#   None,
#   83.62614782083334),
#  ('Bach/Prelude/bwv_856/LuoJ01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_856',
#   None,
#   57.033437500000005),
#  ('Bach/Prelude/bwv_857/Bult-ItoS02.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--2.midi',
#   'Bach/Prelude/bwv_857',
#   None,
#   99.75125),
#  ('Bach/Prelude/bwv_857/Lisiecki04.mid',
#   '2008/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_857',
#   None,
#   108.93386417083335),
#  ('Bach/Prelude/bwv_857/ToA01.mid',
#   '2017/MIDI-Unprocessed_048_PIANO048_MID--AUDIO-split_07-06-17_Piano-e_2-05_wav--1.midi',
#   'Bach/Prelude/bwv_857',
#   None,
#   125.94883760000002),
#  ('Bach/Prelude/bwv_857/WangA01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_18_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_857',
#   None,
#   133.7459375),
#  ('Bach/Prelude/bwv_857/YuP01.mid',
#   '2017/MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--1.midi',
#   'Bach/Prelude/bwv_857',
#   None,
#   112.50865389166667),
#  ('Bach/Prelude/bwv_858/VuV01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_858',
#   None,
#   79.46875),
#  ('Bach/Prelude/bwv_858/Zhang01.mid',
#   '2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_02_Track02_wav.midi',
#   'Bach/Prelude/bwv_858',
#   None,
#   86.19879983750002),
#  ('Bach/Prelude/bwv_860/Ko04.mid',
#   '2008/MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_860',
#   None,
#   48.21906290208334),
#  ('Bach/Prelude/bwv_860/Nikiforov05.mid',
#   '2008/MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--2.midi',
#   'Bach/Prelude/bwv_860',
#   None,
#   49.23508950833334),
#  ('Bach/Prelude/bwv_860/Tetzloff04.mid',
#   '2008/MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MID--AUDIO_15_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_860',
#   None,
#   47.93701135208334),
#  ('Bach/Prelude/bwv_860/TuanS01.mid',
#   '2017/MIDI-Unprocessed_057_PIANO057_MID--AUDIO-split_07-07-17_Piano-e_1-07_wav--1.midi',
#   'Bach/Prelude/bwv_860',
#   None,
#   50.113295470833336),
#  ('Bach/Prelude/bwv_860/YoungS01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_860',
#   None,
#   46.7665625),
#  ('Bach/Prelude/bwv_860/ZhangH04.mid',
#   '2008/MIDI-Unprocessed_18_R1_2008_01-04_ORIG_MID--AUDIO_18_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_860',
#   None,
#   48.44769559791667),
#  ('Bach/Prelude/bwv_862/Song04.mid',
#   '2008/MIDI-Unprocessed_13_R1_2008_01-04_ORIG_MID--AUDIO_13_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_862',
#   None,
#   74.0705831875),
#  ('Bach/Prelude/bwv_863/LeeN01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_863',
#   None,
#   101.71875),
#  ('Bach/Prelude/bwv_863/Shychko01.mid',
#   '2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_07_Track07_wav.midi',
#   'Bach/Prelude/bwv_863',
#   None,
#   101.00223270416667),
#  ('Bach/Prelude/bwv_863/TongB01.mid',
#   '2017/MIDI-Unprocessed_056_PIANO056_MID--AUDIO-split_07-07-17_Piano-e_1-05_wav--1.midi',
#   'Bach/Prelude/bwv_863',
#   None,
#   92.94880625000002),
#  ('Bach/Prelude/bwv_864/SunD01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_864',
#   None,
#   63.696875000000006),
#  ('Bach/Prelude/bwv_865/Rizikov01.mid',
#   '2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav.midi',
#   'Bach/Prelude/bwv_865',
#   None,
#   59.08659459375001),
#  ('Bach/Prelude/bwv_865/Teo01.mid',
#   '2011/MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_14_Track14_wav.midi',
#   'Bach/Prelude/bwv_865',
#   None,
#   57.29599460208334),
#  ('Bach/Prelude/bwv_865/ZhangE01.mid',
#   '2017/MIDI-Unprocessed_067_PIANO067_MID--AUDIO-split_07-07-17_Piano-e_3-03_wav--1.midi',
#   'Bach/Prelude/bwv_865',
#   None,
#   60.552407952083335),
#  ('Bach/Prelude/bwv_867/HuNY01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_867',
#   None,
#   168.30625),
#  ('Bach/Prelude/bwv_867/Sham01.mid',
#   '2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_12_Track12_wav.midi',
#   'Bach/Prelude/bwv_867',
#   None,
#   177.15721958125002),
#  ('Bach/Prelude/bwv_868/GonzalezJ05.mid',
#   '2014/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--2.midi',
#   'Bach/Prelude/bwv_868',
#   None,
#   63.4039063875),
#  ('Bach/Prelude/bwv_870/ChenW01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_20_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_870',
#   None,
#   155.364375),
#  ('Bach/Prelude/bwv_870/LeeE01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_17_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_870',
#   None,
#   143.39281250000002),
#  ('Bach/Prelude/bwv_870/MaximovI01.mid',
#   '2014/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_16_R1_2014_wav--1.midi',
#   'Bach/Prelude/bwv_870',
#   None,
#   153.60805191041666),
#  ('Bach/Prelude/bwv_873/Lisiecki13.mid',
#   '2008/MIDI-Unprocessed_11_R3_2008_01-04_ORIG_MID--AUDIO_11_R3_2008_wav--1.midi',
#   'Bach/Prelude/bwv_873',
#   None,
#   256.18293568125006),
#  ('Bach/Prelude/bwv_874/WongWY01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_19_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_874',
#   None,
#   167.94500000000002),
#  ('Bach/Prelude/bwv_875/Ahfat01.mid',
#   '2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_02_Track02_wav.midi',
#   'Bach/Prelude/bwv_875',
#   None,
#   95.12402199166668),
#  ('Bach/Prelude/bwv_875/CaoJ01.mid',
#   '2017/MIDI-Unprocessed_065_PIANO065_MID--AUDIO-split_07-07-17_Piano-e_3-01_wav--1.midi',
#   'Bach/Prelude/bwv_875',
#   None,
#   87.55457035625001),
#  ('Bach/Prelude/bwv_875/HONG04.mid',
#   '2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG_MID--AUDIO_09_R1_2004_01_Track01_wav.midi',
#   'Bach/Prelude/bwv_875',
#   None,
#   87.16247596666666),
#  ('Bach/Prelude/bwv_876/SirajA01.mid',
#   '2017/MIDI-Unprocessed_061_PIANO061_MID--AUDIO-split_07-07-17_Piano-e_2-05_wav--1.midi',
#   'Bach/Prelude/bwv_876',
#   None,
#   130.17213221041666),
#  ('Bach/Prelude/bwv_876/Song01.mid',
#   '2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_02_Track02_wav.midi',
#   'Bach/Prelude/bwv_876',
#   None,
#   133.31850272083332),
#  ('Bach/Prelude/bwv_880/LeungR01.mid',
#   '2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-split_07-07-17_Piano-e_3-02_wav--1.midi',
#   'Bach/Prelude/bwv_880',
#   None,
#   205.46921228958334),
#  ('Bach/Prelude/bwv_880/WangA04.mid',
#   '2008/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_880',
#   None,
#   166.73520113333336),
#  ('Bach/Prelude/bwv_883/GuoE01.mid',
#   '2017/MIDI-Unprocessed_050_PIANO050_MID--AUDIO-split_07-06-17_Piano-e_3-01_wav--1.midi',
#   'Bach/Prelude/bwv_883',
#   None,
#   173.50550671041668),
#  ('Bach/Prelude/bwv_883/LuM01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_10_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_883',
#   None,
#   163.5021875),
#  ('Bach/Prelude/bwv_884/LiA01.mid',
#   '2017/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--1.midi',
#   'Bach/Prelude/bwv_884',
#   None,
#   69.61224561875001),
#  ('Bach/Prelude/bwv_885/Guo01.mid',
#   '2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_02_Track02_wav.midi',
#   'Bach/Prelude/bwv_885',
#   None,
#   146.51082294583335),
#  ('Bach/Prelude/bwv_885/Huang04.mid',
#   '2008/MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_885',
#   None,
#   157.47878208333336),
#  ('Bach/Prelude/bwv_885/JeonH01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_885',
#   None,
#   174.89375),
#  ('Bach/Prelude/bwv_887/LiYZ01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_887',
#   None,
#   111.878125),
#  ('Bach/Prelude/bwv_888/ZhaoK01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_888',
#   None,
#   101.7946875),
#  ('Bach/Prelude/bwv_889/Giesbrecht01.mid',
#   '2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_07_Track07_wav.midi',
#   'Bach/Prelude/bwv_889',
#   None,
#   143.87620505833337),
#  ('Bach/Prelude/bwv_889/LiuY01.mid',
#   '2017/MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--1.midi',
#   'Bach/Prelude/bwv_889',
#   None,
#   137.46273742708334),
#  ('Bach/Prelude/bwv_889/MunA01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--1.midi',
#   'Bach/Prelude/bwv_889',
#   None,
#   137.275),
#  ('Bach/Prelude/bwv_889/Wang01.mid',
#   '2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_14_Track14_wav.midi',
#   'Bach/Prelude/bwv_889',
#   None,
#   148.43069656458334),
#  ('Bach/Prelude/bwv_889/YangY02.mid',
#   '2017/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--2.midi',
#   'Bach/Prelude/bwv_889',
#   None,
#   130.19991001458334),
#  ('Bach/Prelude/bwv_889/ZhangW02.mid',
#   '2017/MIDI-Unprocessed_062_PIANO062_MID--AUDIO-split_07-07-17_Piano-e_2-07_wav--2.midi',
#   'Bach/Prelude/bwv_889',
#   None,
#   122.81315086041668),
#  ('Bach/Prelude/bwv_891/BLINOV04.mid',
#   '2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_01_Track01_wav.midi',
#   'Bach/Prelude/bwv_891',
#   None,
#   154.5129673),
#  ('Bach/Prelude/bwv_891/Duepree06.mid',
#   '2008/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_891',
#   None,
#   140.65718490625002),
#  ('Bach/Prelude/bwv_892/Hou01.mid',
#   '2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_12_Track12_wav.midi',
#   'Bach/Prelude/bwv_892',
#   None,
#   99.46804321250002),
#  ('Bach/Prelude/bwv_892/KabuliL01.mid',
#   '2017/MIDI-Unprocessed_055_PIANO055_MID--AUDIO-split_07-07-17_Piano-e_1-04_wav--1.midi',
#   'Bach/Prelude/bwv_892',
#   None,
#   112.51720090833335),
#  ('Bach/Prelude/bwv_893/Kleisen04.mid',
#   '2008/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_893',
#   None,
#   129.46272982708334),
#  ('Bach/Prelude/bwv_893/Levitsky04.mid',
#   '2008/MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--1.midi',
#   'Bach/Prelude/bwv_893',
#   None,
#   134.57491417083335),
#  ('Bach/Prelude/bwv_893/Wong01.mid',
#   '2013/ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--1.midi',
#   'Bach/Prelude/bwv_893',
#   None,
#   146.18817306666668),
#  ('Bach/Fugue/bwv_846/Shi05.mid',
#   '2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_01_Track01_wav.midi',
#   'Bach/Fugue/bwv_846',
#   143.54166666666666,
#   None),
#  ('Bach/Fugue/bwv_848/Denisova06.mid',
#   '2008/MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MID--AUDIO_02_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_848',
#   68.2890625,
#   None),
#  ('Bach/Fugue/bwv_848/Lee01.mid',
#   '2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1-D3_07_Track07_wav.midi',
#   'Bach/Fugue/bwv_848',
#   73.78906249999999,
#   None),
#  ('Bach/Fugue/bwv_848/LeeSH01.mid',
#   '2017/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-split_07-06-17_Piano-e_2-06_wav--1.midi',
#   'Bach/Fugue/bwv_848',
#   82.67916666666666,
#   None),
#  ('Bach/Fugue/bwv_848/Lin04.mid',
#   '2008/MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MID--AUDIO_10_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_848',
#   74.35286458333333,
#   None),
#  ('Bach/Fugue/bwv_848/Lou01.mid',
#   '2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1-D9_08_Track08_wav.midi',
#   'Bach/Fugue/bwv_848',
#   74.58072916666666,
#   None),
#  ('Bach/Fugue/bwv_848/MiyashitaM01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_09_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_848',
#   78.60729166666667,
#   None),
#  ('Bach/Fugue/bwv_848/Mizumoto03.mid',
#   '2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_15_Track15_wav.midi',
#   'Bach/Fugue/bwv_848',
#   71.86588541666667,
#   None),
#  ('Bach/Fugue/bwv_848/SunY01.mid',
#   '2017/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-split_07-07-17_Piano-e_2-03_wav--1.midi',
#   'Bach/Fugue/bwv_848',
#   69.64375000000001,
#   None),
#  ('Bach/Fugue/bwv_848/Zhou01.mid',
#   '2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_02_Track02_wav.midi',
#   'Bach/Fugue/bwv_848',
#   67.77864583333333,
#   None),
#  ('Bach/Fugue/bwv_854/LuA01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_854',
#   90.78229166666667,
#   None),
#  ('Bach/Fugue/bwv_854/MiyashitaM01.mid',
#   '2017/MIDI-Unprocessed_051_PIANO051_MID--AUDIO-split_07-06-17_Piano-e_3-02_wav--1.midi',
#   'Bach/Fugue/bwv_854',
#   81.78020833333333,
#   None),
#  ('Bach/Fugue/bwv_854/Ozaki01.mid',
#   '2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1-D1_15_Track15_wav.midi',
#   'Bach/Fugue/bwv_854',
#   84.93880208333333,
#   None),
#  ('Bach/Fugue/bwv_854/Richardson01.mid',
#   '2013/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_R1_2013_wav--1.midi',
#   'Bach/Fugue/bwv_854',
#   93.61588541666666,
#   None),
#  ('Bach/Fugue/bwv_854/WangA01.mid',
#   '2017/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-split_07-06-17_Piano-e_1-01_wav--1.midi',
#   'Bach/Fugue/bwv_854',
#   85.79791666666667,
#   None),
#  ('Bach/Fugue/bwv_856/LuoJ01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_06_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_856',
#   58.95729166666666,
#   None),
#  ('Bach/Fugue/bwv_857/Bult-ItoS02.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_05_R1_2015_wav--2.midi',
#   'Bach/Fugue/bwv_857',
#   106.07916666666667,
#   None),
#  ('Bach/Fugue/bwv_857/Lisiecki04.mid',
#   '2008/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MID--AUDIO_11_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_857',
#   112.33203125,
#   None),
#  ('Bach/Fugue/bwv_857/ToA01.mid',
#   '2017/MIDI-Unprocessed_048_PIANO048_MID--AUDIO-split_07-06-17_Piano-e_2-05_wav--1.midi',
#   'Bach/Fugue/bwv_857',
#   131.91145833333334,
#   None),
#  ('Bach/Fugue/bwv_857/WangA01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_18_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_857',
#   136.565625,
#   None),
#  ('Bach/Fugue/bwv_857/YuP01.mid',
#   '2017/MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--1.midi',
#   'Bach/Fugue/bwv_857',
#   115.9125,
#   None),
#  ('Bach/Fugue/bwv_858/VuV01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_858',
#   82.83854166666666,
#   None),
#  ('Bach/Fugue/bwv_858/Zhang01.mid',
#   '2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1-D3_02_Track02_wav.midi',
#   'Bach/Fugue/bwv_858',
#   89.34765624999999,
#   None),
#  ('Bach/Fugue/bwv_860/Ko04.mid',
#   '2008/MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MID--AUDIO_07_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_860',
#   49.82421874999999,
#   None),
#  ('Bach/Fugue/bwv_860/Nikiforov05.mid',
#   '2008/MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--2.midi',
#   'Bach/Fugue/bwv_860',
#   49.967447916666664,
#   None),
#  ('Bach/Fugue/bwv_860/Tetzloff04.mid',
#   '2008/MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MID--AUDIO_15_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_860',
#   49.924479166666664,
#   None),
#  ('Bach/Fugue/bwv_860/TuanS01.mid',
#   '2017/MIDI-Unprocessed_057_PIANO057_MID--AUDIO-split_07-07-17_Piano-e_1-07_wav--1.midi',
#   'Bach/Fugue/bwv_860',
#   51.35520833333333,
#   None),
#  ('Bach/Fugue/bwv_860/YoungS01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_860',
#   50.84791666666666,
#   None),
#  ('Bach/Fugue/bwv_860/ZhangH04.mid',
#   '2008/MIDI-Unprocessed_18_R1_2008_01-04_ORIG_MID--AUDIO_18_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_860',
#   50.234375,
#   None),
#  ('Bach/Fugue/bwv_862/Song04.mid',
#   '2008/MIDI-Unprocessed_13_R1_2008_01-04_ORIG_MID--AUDIO_13_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_862',
#   77.61588541666667,
#   None),
#  ('Bach/Fugue/bwv_863/LeeN01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_07_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_863',
#   107.47604166666666,
#   None),
#  ('Bach/Fugue/bwv_863/Shychko01.mid',
#   '2011/MIDI-Unprocessed_11_R1_2011_MID--AUDIO_R1-D4_07_Track07_wav.midi',
#   'Bach/Fugue/bwv_863',
#   104.09114583333333,
#   None),
#  ('Bach/Fugue/bwv_863/TongB01.mid',
#   '2017/MIDI-Unprocessed_056_PIANO056_MID--AUDIO-split_07-07-17_Piano-e_1-05_wav--1.midi',
#   'Bach/Fugue/bwv_863',
#   96.57187499999999,
#   None),
#  ('Bach/Fugue/bwv_864/SunD01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_16_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_864',
#   66.09791666666666,
#   None),
#  ('Bach/Fugue/bwv_865/Rizikov01.mid',
#   '2011/MIDI-Unprocessed_19_R1_2011_MID--AUDIO_R1-D7_12_Track12_wav.midi',
#   'Bach/Fugue/bwv_865',
#   62.869791666666664,
#   None),
#  ('Bach/Fugue/bwv_865/Teo01.mid',
#   '2011/MIDI-Unprocessed_25_R1_2011_MID--AUDIO_R1-D9_14_Track14_wav.midi',
#   'Bach/Fugue/bwv_865',
#   59.01302083333333,
#   None),
#  ('Bach/Fugue/bwv_865/ZhangE01.mid',
#   '2017/MIDI-Unprocessed_067_PIANO067_MID--AUDIO-split_07-07-17_Piano-e_3-03_wav--1.midi',
#   'Bach/Fugue/bwv_865',
#   62.190625,
#   None),
#  ('Bach/Fugue/bwv_867/HuNY01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_22_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_867',
#   173.12395833333332,
#   None),
#  ('Bach/Fugue/bwv_867/Sham01.mid',
#   '2011/MIDI-Unprocessed_16_R1_2011_MID--AUDIO_R1-D6_12_Track12_wav.midi',
#   'Bach/Fugue/bwv_867',
#   180.58203124999997,
#   None),
#  ('Bach/Fugue/bwv_868/GonzalezJ05.mid',
#   '2014/MIDI-UNPROCESSED_01-03_R1_2014_MID--AUDIO_03_R1_2014_wav--2.midi',
#   'Bach/Fugue/bwv_868',
#   64.62369791666666,
#   None),
#  ('Bach/Fugue/bwv_870/ChenW01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_20_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_870',
#   160.725,
#   None),
#  ('Bach/Fugue/bwv_870/LeeE01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_17_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_870',
#   145.90625,
#   None),
#  ('Bach/Fugue/bwv_870/MaximovI01.mid',
#   '2014/MIDI-UNPROCESSED_16-18_R1_2014_MID--AUDIO_16_R1_2014_wav--1.midi',
#   'Bach/Fugue/bwv_870',
#   155.84895833333331,
#   None),
#  ('Bach/Fugue/bwv_873/Lisiecki13.mid',
#   '2008/MIDI-Unprocessed_11_R3_2008_01-04_ORIG_MID--AUDIO_11_R3_2008_wav--1.midi',
#   'Bach/Fugue/bwv_873',
#   259.9231770833333,
#   None),
#  ('Bach/Fugue/bwv_874/WongWY01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_19_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_874',
#   174.1625,
#   None),
#  ('Bach/Fugue/bwv_875/Ahfat01.mid',
#   '2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1-D6_02_Track02_wav.midi',
#   'Bach/Fugue/bwv_875',
#   98.98697916666667,
#   None),
#  ('Bach/Fugue/bwv_875/CaoJ01.mid',
#   '2017/MIDI-Unprocessed_065_PIANO065_MID--AUDIO-split_07-07-17_Piano-e_3-01_wav--1.midi',
#   'Bach/Fugue/bwv_875',
#   88.54895833333333,
#   None),
#  ('Bach/Fugue/bwv_876/SirajA01.mid',
#   '2017/MIDI-Unprocessed_061_PIANO061_MID--AUDIO-split_07-07-17_Piano-e_2-05_wav--1.midi',
#   'Bach/Fugue/bwv_876',
#   132.09687499999998,
#   None),
#  ('Bach/Fugue/bwv_876/Song01.mid',
#   '2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1-D5_02_Track02_wav.midi',
#   'Bach/Fugue/bwv_876',
#   136.32291666666666,
#   None),
#  ('Bach/Fugue/bwv_880/LeungR01.mid',
#   '2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-split_07-07-17_Piano-e_3-02_wav--1.midi',
#   'Bach/Fugue/bwv_880',
#   206.47708333333333,
#   None),
#  ('Bach/Fugue/bwv_880/WangA04.mid',
#   '2008/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_880',
#   169.18098958333331,
#   None),
#  ('Bach/Fugue/bwv_883/GuoE01.mid',
#   '2017/MIDI-Unprocessed_050_PIANO050_MID--AUDIO-split_07-06-17_Piano-e_3-01_wav--1.midi',
#   'Bach/Fugue/bwv_883',
#   180.35833333333332,
#   None),
#  ('Bach/Fugue/bwv_883/LuM01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_10_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_883',
#   165.59791666666666,
#   None),
#  ('Bach/Fugue/bwv_884/LiA01.mid',
#   '2017/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-split_07-07-17_Piano-e_2-04_wav--1.midi',
#   'Bach/Fugue/bwv_884',
#   70.88437499999999,
#   None),
#  ('Bach/Fugue/bwv_885/Guo01.mid',
#   '2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1-D8_02_Track02_wav.midi',
#   'Bach/Fugue/bwv_885',
#   148.1875,
#   None),
#  ('Bach/Fugue/bwv_885/Huang04.mid',
#   '2008/MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_885',
#   159.265625,
#   None),
#  ('Bach/Fugue/bwv_885/JeonH01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_885',
#   177.3010416666667,
#   None),
#  ('Bach/Fugue/bwv_887/LiYZ01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_03_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_887',
#   115.17395833333333,
#   None),
#  ('Bach/Fugue/bwv_888/ZhaoK01.mid',
#   '2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_13_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_888',
#   102.83645833333333,
#   None),
#  ('Bach/Fugue/bwv_889/Giesbrecht01.mid',
#   '2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1-D6_07_Track07_wav.midi',
#   'Bach/Fugue/bwv_889',
#   149.02604166666666,
#   None),
#  ('Bach/Fugue/bwv_889/LiuY01.mid',
#   '2017/MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--1.midi',
#   'Bach/Fugue/bwv_889',
#   139.86874999999998,
#   None),
#  ('Bach/Fugue/bwv_889/MunA01.mid',
#   '2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-from_mp3_12_R1_2015_wav--1.midi',
#   'Bach/Fugue/bwv_889',
#   140.48958333333334,
#   None),
#  ('Bach/Fugue/bwv_889/Wang01.mid',
#   '2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1-D2_14_Track14_wav.midi',
#   'Bach/Fugue/bwv_889',
#   149.85807291666666,
#   None),
#  ('Bach/Fugue/bwv_889/YangY02.mid',
#   '2017/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-split_07-06-17_Piano-e_3-03_wav--2.midi',
#   'Bach/Fugue/bwv_889',
#   132.51979166666666,
#   None),
#  ('Bach/Fugue/bwv_889/ZhangW02.mid',
#   '2017/MIDI-Unprocessed_062_PIANO062_MID--AUDIO-split_07-07-17_Piano-e_2-07_wav--2.midi',
#   'Bach/Fugue/bwv_889',
#   126.80625,
#   None),
#  ('Bach/Fugue/bwv_891/BLINOV04.mid',
#   '2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG_MID--AUDIO_03_R1_2004_01_Track01_wav.midi',
#   'Bach/Fugue/bwv_891',
#   155.37395833333335,
#   None),
#  ('Bach/Fugue/bwv_891/Duepree06.mid',
#   '2008/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MID--AUDIO_03_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_891',
#   142.87890625,
#   None),
#  ('Bach/Fugue/bwv_892/Hou01.mid',
#   '2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_12_Track12_wav.midi',
#   'Bach/Fugue/bwv_892',
#   100.9765625,
#   None),
#  ('Bach/Fugue/bwv_892/KabuliL01.mid',
#   '2017/MIDI-Unprocessed_055_PIANO055_MID--AUDIO-split_07-07-17_Piano-e_1-04_wav--1.midi',
#   'Bach/Fugue/bwv_892',
#   115.39791666666667,
#   None),
#  ('Bach/Fugue/bwv_893/Kleisen04.mid',
#   '2008/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MID--AUDIO_06_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_893',
#   133.07291666666666,
#   None),
#  ('Bach/Fugue/bwv_893/Levitsky04.mid',
#   '2008/MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MID--AUDIO_09_R1_2008_wav--1.midi',
#   'Bach/Fugue/bwv_893',
#   135.56119791666666,
#   None),
#  ('Bach/Fugue/bwv_893/Wong01.mid',
#   '2013/ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--1.midi',
#   'Bach/Fugue/bwv_893',
#   149.13411458333331,
#   None)]

# %% [markdown]
# ## let's replace the replaceable virtuoso MIDI with maestro midi

# %%
# To split a midi we want to copy to a new file:
#   -first instrument (only one instrument: piano)
#     - all notes in the interval
#     - all control changes in the interval
def split_midi(midi_path, start, end):
    #import the midi
    midi = pm.PrettyMIDI(midi_path)
    # Depending on the case of start and stop we go for different options: 
    # the idea is to interact with the maestro midi less as possible
    if start is None and end is None: 
        #just save the midi as it is changing the name
        return midi, None, None
    elif start is None and end is not None:
        #truncate the current midi evoiding the notes and cc after a certain time
        first = midi.instruments[0].notes[0].start
        midi.instruments[0].notes = [note for note in midi.instruments[0].notes 
                                     if (note.start < end +first) ]
        midi.instruments[0].control_changes = [cc for cc in midi.instruments[0].control_changes
                                     if (cc.time < end +first) ]
        return midi,None, midi.get_end_time()
    elif start is not None and end is None:
        #delete the first part (the prelude). Shift the notes back in order for them to be almost at the beginning
        first = get_midi_notes(midi)[0][0]  #get the onset of the first note, starting point where are the tempos are computed from
        # we want the first note to be after 0.5 s from the beginning. There should be no interaction with the prelude in this way
        midi.instruments[0].notes = [pm.Note(velocity=note.velocity, pitch=note.pitch, start=note.start-start -first +0.5, end=note.end-start-first +0.5) 
                   for note in midi.instruments[0].notes 
                   if (note.start >= start + first - 0.5)]
        midi.control_changes = [pm.ControlChange(number=cc.number, value=cc.value, time=cc.time-start - first + 0.5)
                            for cc in midi.instruments[0].control_changes
                            if (cc.time >= start + first - 0.5 )]
        return midi, start +first -0.5,None
    else:
        raise Exception("Case not considered")

# %%
# attempt to split a midi file
index = 145
print(midi_to_save[index])
nmidi, start, stop = split_midi(str(Path(MAESTRO_BPATH,midi_to_save[index][1])),midi_to_save[index][3],midi_to_save[index][4])
# Out:
# ('Bach/Fugue/bwv_892/Hou01.mid', '2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1-D3_12_Track12_wav.midi', 'Bach/Fugue/bwv_892', 100.9765625, None)

# %%
print("start",start,"stop",stop)
# import IPython.display as ipd
# ipd.Audio(nmidi.synthesize(fs=4600),rate=4600)
nmidi.write(str(Path('../temp_midi.mid')))
# Out:
# start 101.43880208333333 stop None

# %%
# overwrite all the songs in virtuoso that are matched with maestro
# the name we chose is the old yamaha file + M + [1,2] if the file was splitted in 2 parts

#format : (virtuosomidi,maestromidi,folder,beginning,end)
correct_annotations = []
for virt, maestro, folder, start, end in midi_to_save:
    #save the new file
    midi, new_start, new_end = split_midi(str(Path(MAESTRO_BPATH,maestro)),start,end)
    midi.write(str(Path(VIRTUOSO_BPATH,virt))[:-4]+"M.mid")
    #delete the old file
    Path(VIRTUOSO_BPATH,virt).unlink()
    #save the corrected annotation
    correct_annotations.append({"virtuoso_path":virt,"maestro_path":maestro,"folder":folder,"start":new_start,"end":new_end})

# %%
#maybe revise?
- check the audio alignment
- check audio for prelude just importing
- check audio for fugues
