# %%
import json
import pretty_midi as pm
import pandas as pd
import numpy as np
from pathlib import Path
import sys

from alignment import (find_match, get_midi_notes, normalize_midi_notes,
                       notes_are_similar)

# %%
# maestro dataframe (from google)
maestro = pd.read_json('maestro-v2.0.0.json')

# virtuoso dataframe (i produce parsing the folders of the dataset)
virtuoso_net = pd.read_pickle("performance_dataframe.pkl")

# %%
maestro.head()
# Out:
#    canonical_composer                canonical_title       split  year  \
# 0          Alban Berg                   Sonata Op. 1       train  2018
# 1          Alban Berg                   Sonata Op. 1       train  2008
# 2          Alban Berg                   Sonata Op. 1       train  2017
# 3  Alexander Scriabin  24 Preludes Op. 11, No. 13-24       train  2004
# 4  Alexander Scriabin               3 Etudes, Op. 65  validation  2006
#
#                                        midi_filename  \
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...
# 1  2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...
# 2  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...
# 3  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...
# 4  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...
#
#                                       audio_filename    duration
# 0  2018/MIDI-Unprocessed_Chamber3_MID--AUDIO_10_R...  698.661160
# 1  2008/MIDI-Unprocessed_03_R2_2008_01-03_ORIG_MI...  759.518471
# 2  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...  464.649433
# 3  2004/MIDI-Unprocessed_XP_21_R1_2004_01_ORIG_MI...  872.640588
# 4  2006/MIDI-Unprocessed_17_R1_2006_01-06_ORIG_MI...  397.857508

# %%
virtuoso_net.head()
# Out:
#   author              folder                         midi2midi_alignment_path  \
# 0   Bach  Bach/Fugue/bwv_846       Bach/Fugue/bwv_846/Shi05_infer_corresp.txt
# 1   Bach  Bach/Fugue/bwv_848  Bach/Fugue/bwv_848/Denisova06_infer_corresp.txt
# 2   Bach  Bach/Fugue/bwv_848       Bach/Fugue/bwv_848/Lee01_infer_corresp.txt
# 3   Bach  Bach/Fugue/bwv_848     Bach/Fugue/bwv_848/LeeSH01_infer_corresp.txt
# 4   Bach  Bach/Fugue/bwv_848       Bach/Fugue/bwv_848/Lin04_infer_corresp.txt
#
#                  performed_midi_path   performer  \
# 0       Bach/Fugue/bwv_846/Shi05.mid       Shi05
# 1  Bach/Fugue/bwv_848/Denisova06.mid  Denisova06
# 2       Bach/Fugue/bwv_848/Lee01.mid       Lee01
# 3     Bach/Fugue/bwv_848/LeeSH01.mid     LeeSH01
# 4       Bach/Fugue/bwv_848/Lin04.mid       Lin04
#
#                             score2midi_alignment  \
# 0       Bach/Fugue/bwv_846/Shi05_infer_match.txt
# 1  Bach/Fugue/bwv_848/Denisova06_infer_match.txt
# 2       Bach/Fugue/bwv_848/Lee01_infer_match.txt
# 3     Bach/Fugue/bwv_848/LeeSH01_infer_match.txt
# 4       Bach/Fugue/bwv_848/Lin04_infer_match.txt
#
#                        score_midi_path  \
# 0  Bach/Fugue/bwv_846/midi_cleaned.mid
# 1  Bach/Fugue/bwv_848/midi_cleaned.mid
# 2  Bach/Fugue/bwv_848/midi_cleaned.mid
# 3  Bach/Fugue/bwv_848/midi_cleaned.mid
# 4  Bach/Fugue/bwv_848/midi_cleaned.mid
#
#                                  score_xml_path          title
# 0  Bach/Fugue/bwv_846/musicxml_cleaned.musicxml  Fugue_bwv_846
# 1  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848
# 2  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848
# 3  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848
# 4  Bach/Fugue/bwv_848/musicxml_cleaned.musicxml  Fugue_bwv_848

# %% [markdown]
# ## Example alignment

# %%
# Use as python alignment.py from the command line.
# Try "python alignment.py -h" for help.
# This output is like running "python alignment.py -c Haydn -v"

# Argument -md maestro
MAESTRO_DIR = Path("./maestro") #you need to download the maestro dataset from https://magenta.tensorflow.org/datasets/maestro
# Argument -vnd .
VIRTUOSO_DIR = Path("./")
# Argument -c Haydn
COMPOSER = 'Haydn' # VirtuosoNet composer (None to search all V-net composers)
# Flag -e
EXHAUSTIVE = False # Search all (even non-matching) MAESTRO composers
# Flag -v
VERBOSE = True
# Argument -o correspondence.json
OUTPUT = Path('correspondence.json')

# %%
# Filter V-Net by chosen composer
v_net = virtuoso_net

if COMPOSER is not None:
    v_net = pd.DataFrame(
        v_net.loc[virtuoso_net.author.str.lower() == COMPOSER.lower()]
    )
    if len(v_net) == 0:
        print(f'Error: No composer matching "{COMPOSER}" found in VirtuosoNet.',
              file=sys.stderr)
        if VERBOSE:
            print('Possible composers are:', file=sys.stderr)
            print(virtuoso_net.groupby('author').size(), file=sys.stderr)

# %%
# Some data storage
vnet_notes = {} # Don't pre-load all notes. Only when we need to and save them here.
maestro_notes = {} # DataFrames are not good for holding lists
matches = {} # Result storage

# %%
# Initial search, only through matching MAESTRO composers
# Still group V-net here by composer, to simplify code in case of no composer given
for composer, group in v_net.groupby('author'):
    if VERBOSE:
        print(f'Searching for matches to composer "{composer}", in closely-'
              'matching MAESTRO composers.')
        print('The first piece will take longer as it must compute note data.')

    filtered_maestro = maestro.loc[
        maestro.canonical_composer.str.lower().str.contains(composer.lower())
    ]
    group.apply(find_match, axis=1, args=(filtered_maestro, vnet_notes,
                                          maestro_notes, matches),
                vnet_base=VIRTUOSO_DIR, maestro_base=MAESTRO_DIR,
                verbose=VERBOSE)
# Out:
# Searching for matches to composer "Haydn", in closely-matching MAESTRO composers.
# The first piece will take longer as it must compute note data.
# Searching for matches to piece "Haydn/Keyboard_Sonatas/31-1/Masycheva01.mid"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/31-1/SCHU02.mid"
# Searching for matches to piece "Haydn/Keyboard_Sonatas

# Searching for matches to piece "Haydn/Keyboard_Sonatas/50-1_no_repeat/Kim01.mid"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/50-1_no_repeat/Meng02.mid"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/50-1_no_repeat/Shi07.mid"
#     Match found: "2009/MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_03_WAV.midi"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/50-1_no_repeat/Tak01.mid"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/50-1_no_repeat/Toscano03.mid"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/50-1_no_repeat/Verbaite01.mid"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/50-1_no_repeat/YoungS02.mid"
#     Match found: "2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--2.midi"
# Searching for matches to piece "Haydn/Keyboard_Sonatas/6-1/ChenC01.mid"

# %%
# Extended search through all MAESTRO pieces
if EXHAUSTIVE:
    # No need to group V-net by composer here
    if VERBOSE:
        print(f'Exhaustively searching MAESTRO for any unmatched pieces.')
        print('The first piece will take longer as it must compute note data.')

    # This saves and UNmatched composers (notice the '~')
    filtered_maestro = maestro.loc[
        ~maestro.canonical_composer.str.lower().str.contains(composer.lower())
    ]
    v_net_filtered = v_net.loc[~v_net.index.isin(matches)]
    v_net_filtered.apply(find_match, axis=1, args=(filtered_maestro, vnet_notes,
                                                   maestro_notes, matches),
                         vnet_base=VIRTUOSO_DIR, maestro_base=MAESTRO_DIR,
                         verbose=VERBOSE)

# %%
# Calculate and aggregate final results
name_matches = {
    v_net.loc[key, 'performed_midi_path']: [maestro.loc[idx, 'midi_filename'] for idx in value]
    for key, value in matches.items()
}

multiple_vnet = [key for key, value in name_matches.items() if len(value) > 1]
unmatched_vnet = list(v_net.loc[~v_net.index.isin(matches), 'performed_midi_path'])

# Multiply matched MAESTRO pieces
# Only check those which we searched
maestro_match_counts = {key: 0 for key in maestro_notes}
for idx_list in matches.values():
    for idx in idx_list:
        maestro_match_counts[idx] += 1
multiple_maestro = [maestro.loc[idx, 'midi_filename']
                    for idx, count in maestro_match_counts.items() if count > 1]
unmatched_maestro = [maestro.loc[idx, 'midi_filename']
                     for idx, count in maestro_match_counts.items() if count == 0]

# %%
# Print results
if VERBOSE:
    print(f'ALL MATCHES ({len(name_matches)}):')
    print(name_matches)
    print()
    print(f'Multiply matched VirtuosoNet pieces ({len(multiple_vnet)}):')
    print('\n'.join(multiple_vnet))
    print()
    print(f'Unmatched VirtuosoNet pieces ({len(unmatched_vnet)}):')
    print('\n'.join(unmatched_vnet))
    print()
    print(f'Multiply matched MAESTRO pieces ({len(multiple_maestro)}):')
    print('\n'.join(multiple_maestro))
    print()
    print(f'Unmatched MAESTRO pieces ({len(unmatched_maestro)}):')
    print('\n'.join(unmatched_maestro))
# Out:
# ALL MATCHES (15):
IDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.midi
# 2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_10_Track10_wav.midi
# 2013/ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_04_R1_2013_wav--2.midi
# 2008/MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--1.midi
# 2013/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--2.midi
# 2013/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_19_R1_2013_wav--2.midi
# 2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_01_Track01_wav.midi
# 2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_02_Track02_wav.midi
# 2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--2.midi
# 2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_14_R1_2015_wav--2.midi
# 2013/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--2.midi
# 2008/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--2.midi
# 2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_04_Track04_wav.midi
# 2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_13_Track13_wav.midi
# 2017/MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--2.midi
# 2018/MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--1.midi
# 2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_10_Track10_wav.midi
# 2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--2.midi

# %%
# Write output to file
OUTPUT.parent.mkdir(parents=True, exist_ok=True)
with OUTPUT.open(mode='w') as file:
    json.dump({'matches': name_matches,
               'multiple_vnet': multiple_vnet,
               'unmatched_vnet': unmatched_vnet,
               'multiple_maestro': multiple_maestro,
               'unmatched_maestro': unmatched_maestro},
              file, indent=4, sort_keys=True)

# %%
# Verify that output was written
with OUTPUT.open(mode='r') as file:
    for line in file:
        print(line)
# Out:
# {
#
#     "matches": {
#
#         "Haydn/Keyboard_Sonatas/31-1/Song05.mid": [
#
#             "2008/MIDI-Unprocessed_13_R1_2008_01-04_ORIG_MID--AUDIO_13_R1_2008_wav--2.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/39-1/Yarden07.mid": [
#
#             "2006/MIDI-Unprocessed_23_R1_2006_01-05_ORIG_MID--AUDIO_23_R1_2006_02_Track02_wav.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/46-1/WongWY02.mid": [
#
#             "2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_19_R1_2015_wav--2.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/46-1/YuP03.mid": [
#
#             "2017/MIDI-Unprocessed_042_PIANO042_MID--AUDIO-split_07-06-17_Piano-e_1-02_wav--3.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/48-1/GarritsonL02.mid": [
#
#             "2014/MIDI-UNPROCESSED_21-22_R1_2014_MID--AUDIO_22_R1_2014_wav--1.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/48-1/PrjevalskayaM02.mid": [
#
#             "2014/MIDI-UNPROCESSED_06-08_R1_2014_MID--AUDIO_08_R1_2014_wav--1.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/EVSTIO01.mid": [
#
#             "2018/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/GalantM02.mid": [
#
#             "2018/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/HamSY02.mid": [
#
#             "2014/MIDI-UNPROCESSED_19-20_R1_2014_MID--AUDIO_20_R1_2014_wav--1.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Huang01.mid": [
#
#             "2008/MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--2.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Huang05.mid": [
#
#             "2008/MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--2.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/JeonH03.mid": [
#
#             "2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_15_R1_2015_wav--3.midi",
#
#             "2013/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_17_R1_2013_wav--2.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/KARYAG06.mid": [
#
#             "2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_08_Track08_wav.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Shi07.mid": [
#
#             "2009/MIDI-Unprocessed_12_R1_2009_03-05_ORIG_MID--AUDIO_12_R1_2009_12_R1_2009_03_WAV.midi"
#
#         ],
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/YoungS02.mid": [
#
#             "2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-from_mp3_21_R1_2015_wav--2.midi"
#
#         ]
#
#     },
#
#     "multiple_maestro": [
#
#         "2008/MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MID--AUDIO_04_R1_2008_wav--2.midi",
#
#         "2018/MIDI-Unprocessed_Recital8_MID--AUDIO_08_R1_2018_wav--1.midi"
#
#     ],
#
#     "multiple_vnet": [
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/JeonH03.mid"
#
#     ],
#
#     "unmatched_maestro": [
#
#         "2006/MIDI-Unprocessed_08_R1_2006_01-04_ORIG_MID--AUDIO_08_R1_2006_Disk1_02_Track02_wav.midi",
#
#         "2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MID--AUDIO_19_R1_2006_02_Track02_wav.midi",
#
#         "2006/MIDI-Unprocessed_02_R1_2006_01-04_ORIG_MID--AUDIO_02_R1_2006_01_Track01_wav.midi",
#
#         "2006/MIDI-Unprocessed_22_R1_2006_01-04_ORIG_MID--AUDIO_22_R1_2006_01_Track01_wav.midi",
#
#         "2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1-D2_03_Track03_wav.midi",
#
#         "2013/ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_R1_2013_wav--2.midi",
#
#         "2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_02_Track02_wav.midi",
#
#         "2011/MIDI-Unprocessed_03_R3_2011_MID--AUDIO_R3-D1_03_Track03_wav.midi",
#
#         "2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_09_Track09_wav.midi",
#
#         "2004/MIDI-Unprocessed_SMF_13_01_2004_01-05_ORIG_MID--AUDIO_13_R1_2004_10_Track10_wav.midi",
#
#         "2013/ORIG-MIDI_01_7_6_13_Group__MID--AUDIO_04_R1_2013_wav--2.midi",
#
#         "2008/MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MID--AUDIO_12_R1_2008_wav--1.midi",
#
#         "2013/ORIG-MIDI_01_7_7_13_Group__MID--AUDIO_14_R1_2013_wav--2.midi",
#
#         "2013/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_19_R1_2013_wav--2.midi",
#
#         "2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_01_Track01_wav.midi",
#
#         "2004/MIDI-Unprocessed_XP_19_R1_2004_01-02_ORIG_MID--AUDIO_19_R1_2004_02_Track02_wav.midi",
#
#         "2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_04_R1_2015_wav--2.midi",
#
#         "2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-from_mp3_14_R1_2015_wav--2.midi",
#
#         "2013/ORIG-MIDI_02_7_7_13_Group__MID--AUDIO_15_R1_2013_wav--2.midi",
#
#         "2008/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MID--AUDIO_16_R1_2008_wav--2.midi",
#
#         "2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1-D1_04_Track04_wav.midi",
#
#         "2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1-D4_13_Track13_wav.midi",
#
#         "2017/MIDI-Unprocessed_054_PIANO054_MID--AUDIO-split_07-07-17_Piano-e_1-02_wav--2.midi",
#
#         "2018/MIDI-Unprocessed_Recital5-7_MID--AUDIO_07_R1_2018_wav--1.midi",
#
#         "2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1-D2_10_Track10_wav.midi",
#
#         "2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-from_mp3_02_R1_2015_wav--2.midi"
#
#     ],
#
#     "unmatched_vnet": [
#
#         "Haydn/Keyboard_Sonatas/31-1/Masycheva01.mid",
#
#         "Haydn/Keyboard_Sonatas/31-1/SCHU02.mid",
#
#         "Haydn/Keyboard_Sonatas/31-1/Zagalskaia02.mid",
#
#         "Haydn/Keyboard_Sonatas/32-1/Pavlovic02.mid",
#
#         "Haydn/Keyboard_Sonatas/32-1/SUDBIN01.mid",
#
#         "Haydn/Keyboard_Sonatas/32-1_no_repeat/Goldberg01.mid",
#
#         "Haydn/Keyboard_Sonatas/32-1_no_repeat/Guzman01.mid",
#
#         "Haydn/Keyboard_Sonatas/32-1_no_repeat/MCVEY01.mid",
#
#         "Haydn/Keyboard_Sonatas/39-1/Yarden02.mid",
#
#         "Haydn/Keyboard_Sonatas/39-2/Yarden07.mid",
#
#         "Haydn/Keyboard_Sonatas/39-3/Yarden07.mid",
#
#         "Haydn/Keyboard_Sonatas/46-1/Bach01.mid",
#
#         "Haydn/Keyboard_Sonatas/46-1/GORDEL01.mid",
#
#         "Haydn/Keyboard_Sonatas/46-1/Shilyaev01.mid",
#
#         "Haydn/Keyboard_Sonatas/48-2/GarritsonL03.mid",
#
#         "Haydn/Keyboard_Sonatas/48-2/PrjevalskayaM03.mid",
#
#         "Haydn/Keyboard_Sonatas/49-1/Hou01.mid",
#
#         "Haydn/Keyboard_Sonatas/49-1/LEE_K01.mid",
#
#         "Haydn/Keyboard_Sonatas/49-1/Soukhovetski01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Day01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Georgieva01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Gorucan01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/HSU01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/HUAN_J01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Kim01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Meng02.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Tak01.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Toscano03.mid",
#
#         "Haydn/Keyboard_Sonatas/50-1_no_repeat/Verbaite01.mid",
#
#         "Haydn/Keyboard_Sonatas/6-1/ChenC01.mid"
#
#     ]
#
# }
