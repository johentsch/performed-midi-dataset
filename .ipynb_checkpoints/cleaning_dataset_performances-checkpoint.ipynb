# %%
import os
import sys
# sys.path.append("../virtuosoNet")
# sys.path.append("C:\\Users\\fosca\\Desktop\\CNAM\\midi_beat_tracking\\FMP_0.1.0")

from pathlib import Path
import pandas as pd
import music21 as m21
import pretty_midi as pm
from  matplotlib import pyplot as plt
# import LibFMP.B
# import LibFMP.C2
# import LibFMP.C6
# %matplotlib inline
import numpy as np
import math
import pandas as pd
import librosa
import soundfile

import IPython.display as ipd

# %%
def cleaned_m2m_df(midi2midi_path):
    m2mdf = pd.read_csv(midi2midi_path,sep="\t",skiprows=1,header=None, index_col=False)
    m2mdf.columns =["alignID", "alignOntime", "alignSitch" ,"alignPitch", "alignOnvel", "refID", "refOntime", "refSitch", "refPitch", "refOnvel","empty"]
    #drop the last column "empty"
    m2mdf = m2mdf.drop(columns=["empty"])
    #drop the rows where the alignOntime is -1 (note not existing in both files midi)
    return m2mdf[m2mdf["alignOntime"] != -1]

def generate_performance_annotations(m2m_df, cl_quant_ann):
    #create the list with the time of all annotations
    quant_ann_time_list = cl_quant_ann["time"].tolist()
    quant_ann_type_list = cl_quant_ann["type"].tolist()
    perf_ann_list = []
    for i,at in enumerate(quant_ann_time_list):
        p_ons=list(m2m_df[(m2m_df["refOntime"]>at-0.020) & (m2m_df["refOntime"]<at+0.020)]["alignOntime"]) #40 ms accepted window
        if len(p_ons) == 0: #no note matching the ann position in the performance
            perf_ann_list.append(None)
            print("missing corrispondency at quant time", at)
        else:
            perf_ann_list.append(np.mean(p_ons))

    # clean the values that are smaller than the value before
    for ind,at in enumerate(perf_ann_list[1:]):
        if (ind >0) and (at is not None) and (perf_ann_list[ind-1] is not None) and (at < perf_ann_list[ind-1]) :
            print("Unexpected value",db,"smaller than the previous",perf_ann_list[ind-1])
            perf_ann_list[ind] = None
    
    #save the index for the none values
    none_indices = [index for index,value in enumerate(perf_ann_list) if value is None]
     
    #check if there are no None at the end (there should no, because of the manual corrections)
    assert(perf_ann_list[-1] is not None)
    #interpolate to fill the None values in the middle
    filled_at = pd.Series(perf_ann_list).interpolate().tolist()
    #fill the values at the beginning
    ind = 0
    while math.isnan(filled_at[ind]): #find the number of None at the beginning
        ind +=1
    for i in range(ind)[::-1]: #fill, starting from the later one
        proposed_value = filled_at[i+1] - (filled_at[i+2]-filled_at[i+1])
        if proposed_value<0: #cap at 0
            proposed_value = 0
        filled_at[i] = proposed_value
    
    #associate the type of annotation
    assert(len(quant_ann_type_list) == len(filled_at))
    perd_ann_dict = dict(zip(filled_at, quant_ann_type_list))
    #add the Warning for the None values
    warnings = False
    for val in none_indices:
        perd_ann_dict[filled_at[val]] += "W"
        warnings = True
    
    return perd_ann_dict ,warnings
    
def beat_downbeat_to_text(annotations,out_path):
    path = Path(out_path)
    #produce the txt
    file_content = ""
    for a in annotations:
        file_content+= str(a) + "\t" + str(a) + "\t" + annotations[a] + "\n"
    with open(out_path,"w") as f:
        f.write(file_content)
        
def annotations_to_audio(midi_path, annotations, out_path):
    midi_data = pm.PrettyMIDI(str(midi_path))
    audio_fs = 6000
    beat = [a for a in annotations if annotations[a][0] == "b"]
    downbeat = [a for a in annotations if annotations[a][0] == "d"]
    midi_audio = midi_data.synthesize(fs=audio_fs)
    audio_beat = librosa.clicks(beat, sr=audio_fs, click_freq=900, length=len(midi_audio))
    audio_downbeat = librosa.clicks(downbeat, sr=audio_fs, click_freq=1200, length=len(midi_audio))
    soundfile.write(out_path,audio_beat + audio_downbeat+ midi_audio,audio_fs)
    

def perform_row_to_annotations(row):
    print("Processing opus", row.folder)
    #load the quantized annotations
    ann_quant_df = pd.read_csv(Path(row.folder,"ann_quant_cleaned.txt"),header=None, names=["time","time2","type"],sep='\t')
    #load the m2m alignment
    m2m = cleaned_m2m_df(row["midi2midi_alignment_path"])
    #generate the annotations
    ann_dict,warnings = generate_performance_annotations(m2m, ann_quant_df)
    #delete the old audio and ann
    Path(row.folder,row.performer + "_ann.txt").unlink(missing_ok=True)
    Path(row.folder,row.performer + "_click.wav").unlink(missing_ok=True)
    #write the annotations to txt
    beat_downbeat_to_text(ann_dict,Path(row.performed_midi_path[:-4] + "_ann.txt"))
    #write the audio
    annotations_to_audio(str(Path(row.performed_midi_path)),ann_dict,Path(row.performed_midi_path[:-4] + "_click.wav"))
    print("done")
    return warnings

# %%
df = pd.read_pickle("performance_dataframe_v2(bach).pkl")
df = df[df["maestro_path"].notna()]
df
# Out:
#     author                folder  \
# 0     Bach    Bach/Fugue/bwv_846
# 1     Bach    Bach/Fugue/bwv_848
# 2     Bach    Bach/Fugue/bwv_848
# 3     Bach    Bach/Fugue/bwv_848
# 4     Bach    Bach/Fugue/bwv_848
# 5     Bach    Bach/Fugue/bwv_848
# 6     Bach    Bach/Fugue/bwv_848
# 7     Bach    Bach/Fugue/bwv_848
# 8     Bach    Bach/Fugue/bwv_848
# 9     Bach    Bach/Fugue/bwv_848
# 10    Bach    Bach/Fugue/bwv_854
# 11    Bach    Bach/Fugue/bwv_854
# 12    Bach    Bach/Fugue/bwv_854
# 13    Bach    Bach/Fugue/bwv_854
# 14    Bach    Bach/Fugue/bwv_854
# 15    Bach    Bach/Fugue/bwv_856
# 16    Bach    Bach/Fugue/bwv_857
# 17    Bach    Bach/Fugue/bwv_857
# 18    Bach    Bach/Fugue/bwv_857
# 19    Bach    Bach/Fugue/bwv_857
# 20    Bach    Bach/Fugue/bwv_857
# 21    Bach    Bach/Fugue/bwv_857
# 22    Bach    Bach/Fugue/bwv_858
# 23    Bach    Bach/Fugue/bwv_858
# 24    Bach    Bach/Fugue/bwv_860
# 25    Bach    Bach/Fugue/bwv_860
# 26    Bach    Bach/Fugue/bwv_860
# 27    Bach    Bach/Fugue/bwv_860
# 28    Bach    Bach/Fugue/bwv_860
# 29    Bach    Bach/Fugue/bwv_860
# ..     ...                   ...
# 136   Bach  Bach/Prelude/bwv_874
# 137   Bach  Bach/Prelude/bwv_874
# 138   Bach  Bach/Prelude/bwv_875
# 139   Bach  Bach/Prelude/bwv_875
# 140   Bach  Bach/Prelude/bwv_875
# 141   Bach  Bach/Prelude/bwv_876
# 142   Bach  Bach/Prelude/bwv_876
# 143   Bach  Bach/Prelude/bwv_880
# 145   Bach  Bach/Prelude/bwv_880
# 146   Bach  Bach/Prelude/bwv_883
# 149   Bach  Bach/Prelude/bwv_883
# 150   Bach  Bach/Prelude/bwv_884
# 152   Bach  Bach/Prelude/bwv_885
# 153   Bach  Bach/Prelude/bwv_885
# 154   Bach  Bach/Prelude/bwv_885
# 157   Bach  Bach/Prelude/bwv_887
# 158   Bach  Bach/Prelude/bwv_888
# 159   Bach  Bach/Prelude/bwv_889
# 160   Bach  Bach/Prelude/bwv_889
# 161   Bach  Bach/Prelude/bwv_889
# 162   Bach  Bach/Prelude/bwv_889
# 163   Bach  Bach/Prelude/bwv_889
# 164   Bach  Bach/Prelude/bwv_889
# 165   Bach  Bach/Prelude/bwv_891
# 166   Bach  Bach/Prelude/bwv_891
# 167   Bach  Bach/Prelude/bwv_892
# 168   Bach  Bach/Prelude/bwv_892
# 169   Bach  Bach/Prelude/bwv_893
# 170   Bach  Bach/Prelude/bwv_893
# 171   Bach  Bach/Prelude/bwv_893
#
#                            midi2midi_alignment_path  \
# 0             Bach/Fugue/bwv_846/Shi05M_corresp.txt
# 1        Bach/Fugue/bwv_848/Denisova06M_corresp.txt
# 2             Bach/Fugue/bwv_848/Lee01M_corresp.txt
# 3           Bach/Fugue/bwv_848/LeeSH01M_corresp.txt
# 4             Bach/Fugue/bwv_848/Lin04M_corresp.txt
# 5             Bach/Fugue/bwv_848/Lou01M_corresp.txt
# 6      Bach/Fugue/bwv_848/MiyashitaM01M_corresp.txt
# 7        Bach/Fugue/bwv_848/Mizumoto03M_corresp.txt
# 8            Bach/Fugue/bwv_848/SunY01M_corresp.txt
# 9            Bach/Fugue/bwv_848/Zhou01M_corresp.txt
# 10            Bach/Fugue/bwv_854/LuA01M_corresp.txt
# 11     Bach/Fugue/bwv_854/MiyashitaM01M_corresp.txt
# 12          Bach/Fugue/bwv_854/Ozaki01M_corresp.txt
# 13     Bach/Fugue/bwv_854/Richardson01M_corresp.txt
# 14          Bach/Fugue/bwv_854/WangA01M_corresp.txt
# 15           Bach/Fugue/bwv_856/LuoJ01M_corresp.txt
# 16      Bach/Fugue/bwv_857/Bult-ItoS02M_corresp.txt
# 17            Bach/Fugue/bwv_857/Lan01M_corresp.txt
# 18       Bach/Fugue/bwv_857/Lisiecki04M_corresp.txt
# 19            Bach/Fugue/bwv_857/ToA01M_corresp.txt
# 20          Bach/Fugue/bwv_857/WangA01M_corresp.txt
# 21            Bach/Fugue/bwv_857/YuP01M_corresp.txt
# 22            Bach/Fugue/bwv_858/VuV01M_corresp.txt
# 23          Bach/Fugue/bwv_858/Zhang01M_corresp.txt
# 24             Bach/Fugue/bwv_860/Ko04M_corresp.txt
# 25      Bach/Fugue/bwv_860/Nikiforov05M_corresp.txt
# 26       Bach/Fugue/bwv_860/Tetzloff04M_corresp.txt
# 27          Bach/Fugue/bwv_860/TuanS01M_corresp.txt
# 28         Bach/Fugue/bwv_860/YoungS01M_corresp.txt
# 29         Bach/Fugue/bwv_860/ZhangH04M_corresp.txt
# ..                                              ...
# 136        Bach/Prelude/bwv_874/Kurz01M_corresp.txt
# 137      Bach/Prelude/bwv_874/WongWY01M_corresp.txt
# 138       Bach/Prelude/bwv_875/Ahfat01M_corresp.txt
# 139        Bach/Prelude/bwv_875/CaoJ01M_corresp.txt
# 140        Bach/Prelude/bwv_875/HONG04M_corresp.txt
# 141      Bach/Prelude/bwv_876/SirajA01M_corresp.txt
# 142        Bach/Prelude/bwv_876/Song01M_corresp.txt
# 143      Bach/Prelude/bwv_880/LeungR01M_corresp.txt
# 145       Bach/Prelude/bwv_880/WangA04M_corresp.txt
# 146        Bach/Prelude/bwv_883/GuoE01M_corresp.txt
# 149         Bach/Prelude/bwv_883/LuM01M_corresp.txt
# 150         Bach/Prelude/bwv_884/LiA01M_corresp.txt
# 152         Bach/Prelude/bwv_885/Guo01M_corresp.txt
# 153       Bach/Prelude/bwv_885/Huang04M_corresp.txt
# 154       Bach/Prelude/bwv_885/JeonH01M_corresp.txt
# 157        Bach/Prelude/bwv_887/LiYZ01M_corresp.txt
# 158       Bach/Prelude/bwv_888/ZhaoK01M_corresp.txt
# 159  Bach/Prelude/bwv_889/Giesbrecht01M_corresp.txt
# 160        Bach/Prelude/bwv_889/LiuY01M_corresp.txt
# 161        Bach/Prelude/bwv_889/MunA01M_corresp.txt
# 162        Bach/Prelude/bwv_889/Wang01M_corresp.txt
# 163       Bach/Prelude/bwv_889/YangY02M_corresp.txt
# 164      Bach/Prelude/bwv_889/ZhangW02M_corresp.txt
# 165      Bach/Prelude/bwv_891/BLINOV04M_corresp.txt
# 166     Bach/Prelude/bwv_891/Duepree06M_corresp.txt
# 167         Bach/Prelude/bwv_892/Hou01M_corresp.txt
# 168     Bach/Prelude/bwv_892/KabuliL01M_corresp.txt
# 169     Bach/Prelude/bwv_893/Kleisen04M_corresp.txt
# 170    Bach/Prelude/bwv_893/Levitsky04M_corresp.txt
# 171        Bach/Prelude/bwv_893/Wong01M_corresp.txt
#
#                         performed_midi_path     performer  \
# 0             Bach/Fugue/bwv_846/Shi05M.mid         Shi05
# 1        Bach/Fugue/bwv_848/Denisova06M.mid    Denisova06
# 2             Bach/Fugue/bwv_848/Lee01M.mid         Lee01
# 3           Bach/Fugue/bwv_848/LeeSH01M.mid       LeeSH01
# 4             Bach/Fugue/bwv_848/Lin04M.mid         Lin04
# 5             Bach/Fugue/bwv_848/Lou01M.mid         Lou01
# 6      Bach/Fugue/bwv_848/MiyashitaM01M.mid  MiyashitaM01
# 7        Bach/Fugue/bwv_848/Mizumoto03M.mid    Mizumoto03
# 8            Bach/Fugue/bwv_848/SunY01M.mid        SunY01
# 9            Bach/Fugue/bwv_848/Zhou01M.mid        Zhou01
# 10            Bach/Fugue/bwv_854/LuA01M.mid         LuA01
# 11     Bach/Fugue/bwv_854/MiyashitaM01M.mid  MiyashitaM01
# 12          Bach/Fugue/bwv_854/Ozaki01M.mid       Ozaki01
# 13     Bach/Fugue/bwv_854/Richardson01M.mid  Richardson01
# 14          Bach/Fugue/bwv_854/WangA01M.mid       WangA01
# 15           Bach/Fugue/bwv_856/LuoJ01M.mid        LuoJ01
# 16      Bach/Fugue/bwv_857/Bult-ItoS02M.mid   Bult-ItoS02
# 17            Bach/Fugue/bwv_857/Lan01M.mid         Lan01
# 18       Bach/Fugue/bwv_857/Lisiecki04M.mid    Lisiecki04
# 19            Bach/Fugue/bwv_857/ToA01M.mid         ToA01
# 20          Bach/Fugue/bwv_857/WangA01M.mid       WangA01
# 21            Bach/Fugue/bwv_857/YuP01M.mid         YuP01
# 22            Bach/Fugue/bwv_858/VuV01M.mid         VuV01
# 23          Bach/Fugue/bwv_858/Zhang01M.mid       Zhang01
# 24             Bach/Fugue/bwv_860/Ko04M.mid          Ko04
# 25      Bach/Fugue/bwv_860/Nikiforov05M.mid   Nikiforov05
# 26       Bach/Fugue/bwv_860/Tetzloff04M.mid    Tetzloff04
# 27          Bach/Fugue/bwv_860/TuanS01M.mid       TuanS01
# 28         Bach/Fugue/bwv_860/YoungS01M.mid      YoungS01
# 29         Bach/Fugue/bwv_860/ZhangH04M.mid      ZhangH04
# ..                                      ...           ...
# 136        Bach/Prelude/bwv_874/Kurz01M.mid        Kurz01
# 137      Bach/Prelude/bwv_874/WongWY01M.mid      WongWY01
# 138       Bach/Prelude/bwv_875/Ahfat01M.mid       Ahfat01
# 139        Bach/Prelude/bwv_875/CaoJ01M.mid        CaoJ01
# 140        Bach/Prelude/bwv_875/HONG04M.mid        HONG04
# 141      Bach/Prelude/bwv_876/SirajA01M.mid      SirajA01
# 142        Bach/Prelude/bwv_876/Song01M.mid        Song01
# 143      Bach/Prelude/bwv_880/LeungR01M.mid      LeungR01
# 145       Bach/Prelude/bwv_880/WangA04M.mid       WangA04
# 146        Bach/Prelude/bwv_883/GuoE01M.mid        GuoE01
# 149         Bach/Prelude/bwv_883/LuM01M.mid         LuM01
# 150         Bach/Prelude/bwv_884/LiA01M.mid         LiA01
# 152         Bach/Prelude/bwv_885/Guo01M.mid         Guo01
# 153       Bach/Prelude/bwv_885/Huang04M.mid       Huang04
# 154       Bach/Prelude/bwv_885/JeonH01M.mid       JeonH01
# 157        Bach/Prelude/bwv_887/LiYZ01M.mid        LiYZ01
# 158       Bach/Prelude/bwv_888/ZhaoK01M.mid       ZhaoK01
# 159  Bach/Prelude/bwv_889/Giesbrecht01M.mid  Giesbrecht01
# 160        Bach/Prelude/bwv_889/LiuY01M.mid        LiuY01
# 161        Bach/Prelude/bwv_889/MunA01M.mid        MunA01
# 162        Bach/Prelude/bwv_889/Wang01M.mid        Wang01
# 163       Bach/Prelude/bwv_889/YangY02M.mid       YangY02
# 164      Bach/Prelude/bwv_889/ZhangW02M.mid      ZhangW02
# 165      Bach/Prelude/bwv_891/BLINOV04M.mid      BLINOV04
# 166     Bach/Prelude/bwv_891/Duepree06M.mid     Duepree06
# 167         Bach/Prelude/bwv_892/Hou01M.mid         Hou01
# 168     Bach/Prelude/bwv_892/KabuliL01M.mid     KabuliL01
# 169     Bach/Prelude/bwv_893/Kleisen04M.mid     Kleisen04
# 170    Bach/Prelude/bwv_893/Levitsky04M.mid    Levitsky04
# 171        Bach/Prelude/bwv_893/Wong01M.mid        Wong01
#
#                                   score2midi_alignment  \
# 0             Bach/Fugue/bwv_846/Shi05_infer_match.txt
# 1        Bach/Fugue/bwv_848/Denisova06_infer_match.txt
# 2             Bach/Fugue/bwv_848/Lee01_infer_match.txt
# 3           Bach/Fugue/bwv_848/LeeSH01_infer_match.txt
# 4             Bach/Fugue/bwv_848/Lin04_infer_match.txt
# 5             Bach/Fugue/bwv_848/Lou01_infer_match.txt
# 6      Bach/Fugue/bwv_848/MiyashitaM01_infer_match.txt
# 7        Bach/Fugue/bwv_848/Mizumoto03_infer_match.txt
# 8            Bach/Fugue/bwv_848/SunY01_infer_match.txt
# 9            Bach/Fugue/bwv_848/Zhou01_infer_match.txt
# 10            Bach/Fugue/bwv_854/LuA01_infer_match.txt
# 11     Bach/Fugue/bwv_854/MiyashitaM01_infer_match.txt
# 12          Bach/Fugue/bwv_854/Ozaki01_infer_match.txt
# 13     Bach/Fugue/bwv_854/Richardson01_infer_match.txt
# 14          Bach/Fugue/bwv_854/WangA01_infer_match.txt
# 15           Bach/Fugue/bwv_856/LuoJ01_infer_match.txt
# 16      Bach/Fugue/bwv_857/Bult-ItoS02_infer_match.txt
# 17            Bach/Fugue/bwv_857/Lan01_infer_match.txt
# 18       Bach/Fugue/bwv_857/Lisiecki04_infer_match.txt
# 19            Bach/Fugue/bwv_857/ToA01_infer_match.txt
# 20          Bach/Fugue/bwv_857/WangA01_infer_match.txt
# 21            Bach/Fugue/bwv_857/YuP01_infer_match.txt
# 22            Bach/Fugue/bwv_858/VuV01_infer_match.txt
# 23          Bach/Fugue/bwv_858/Zhang01_infer_match.txt
# 24             Bach/Fugue/bwv_860/Ko04_infer_match.txt
# 25      Bach/Fugue/bwv_860/Nikiforov05_infer_match.txt
# 26       Bach/Fugue/bwv_860/Tetzloff04_infer_match.txt
# 27          Bach/Fugue/bwv_860/TuanS01_infer_match.txt
# 28         Bach/Fugue/bwv_860/YoungS01_infer_match.txt
# 29         Bach/Fugue/bwv_860/ZhangH04_infer_match.txt
# ..                                                 ...
# 136        Bach/Prelude/bwv_874/Kurz01_infer_match.txt
# 137      Bach/Prelude/bwv_874/WongWY01_infer_match.txt
# 138       Bach/Prelude/bwv_875/Ahfat01_infer_match.txt
# 139        Bach/Prelude/bwv_875/CaoJ01_infer_match.txt
# 140        Bach/Prelude/bwv_875/HONG04_infer_match.txt
# 141      Bach/Prelude/bwv_876/SirajA01_infer_match.txt
# 142        Bach/Prelude/bwv_876/Song01_infer_match.txt
# 143      Bach/Prelude/bwv_880/LeungR01_infer_match.txt
# 145       Bach/Prelude/bwv_880/WangA04_infer_match.txt
# 146        Bach/Prelude/bwv_883/GuoE01_infer_match.txt
# 149         Bach/Prelude/bwv_883/LuM01_infer_match.txt
# 150         Bach/Prelude/bwv_884/LiA01_infer_match.txt
# 152         Bach/Prelude/bwv_885/Guo01_infer_match.txt
# 153       Bach/Prelude/bwv_885/Huang04_infer_match.txt
# 154       Bach/Prelude/bwv_885/JeonH01_infer_match.txt
# 157        Bach/Prelude/bwv_887/LiYZ01_infer_match.txt
# 158       Bach/Prelude/bwv_888/ZhaoK01_infer_match.txt
# 159  Bach/Prelude/bwv_889/Giesbrecht01_infer_match.txt
# 160        Bach/Prelude/bwv_889/LiuY01_infer_match.txt
# 161        Bach/Prelude/bwv_889/MunA01_infer_match.txt
# 162        Bach/Prelude/bwv_889/Wang01_infer_match.txt
# 163       Bach/Prelude/bwv_889/YangY02_infer_match.txt
# 164      Bach/Prelude/bwv_889/ZhangW02_infer_match.txt
# 165      Bach/Prelude/bwv_891/BLINOV04_infer_match.txt
# 166     Bach/Prelude/bwv_891/Duepree06_infer_match.txt
# 167         Bach/Prelude/bwv_892/Hou01_infer_match.txt
# 168     Bach/Prelude/bwv_892/KabuliL01_infer_match.txt
# 169     Bach/Prelude/bwv_893/Kleisen04_infer_match.txt
# 170    Bach/Prelude/bwv_893/Levitsky04_infer_match.txt
# 171        Bach/Prelude/bwv_893/Wong01_infer_match.txt
#
#                            score_midi_path  \
# 0      Bach/Fugue/bwv_846/midi_cleaned.mid
# 1      Bach/Fugue/bwv_848/midi_cleaned.mid
# 2      Bach/Fugue/bwv_848/midi_cleaned.mid
# 3      Bach/Fugue/bwv_848/midi_cleaned.mid
# 4      Bach/Fugue/bwv_848/midi_cleaned.mid
# 5      Bach/Fugue/bwv_848/midi_cleaned.mid
# 6      Bach/Fugue/bwv_848/midi_cleaned.mid
# 7      Bach/Fugue/bwv_848/midi_cleaned.mid
# 8      Bach/Fugue/bwv_848/midi_cleaned.mid
# 9      Bach/Fugue/bwv_848/midi_cleaned.mid
# 10     Bach/Fugue/bwv_854/midi_cleaned.mid
# 11     Bach/Fugue/bwv_854/midi_cleaned.mid
# 12     Bach/Fugue/bwv_854/midi_cleaned.mid
# 13     Bach/Fugue/bwv_854/midi_cleaned.mid
# 14     Bach/Fugue/bwv_854/midi_cleaned.mid
# 15     Bach/Fugue/bwv_856/midi_cleaned.mid
# 16     Bach/Fugue/bwv_857/midi_cleaned.mid
# 17     Bach/Fugue/bwv_857/midi_cleaned.mid
# 18     Bach/Fugue/bwv_857/midi_cleaned.mid
# 19     Bach/Fugue/bwv_857/midi_cleaned.mid
# 20     Bach/Fugue/bwv_857/midi_cleaned.mid
# 21     Bach/Fugue/bwv_857/midi_cleaned.mid
# 22     Bach/Fugue/bwv_858/midi_cleaned.mid
# 23     Bach/Fugue/bwv_858/midi_cleaned.mid
# 24     Bach/Fugue/bwv_860/midi_cleaned.mid
# 25     Bach/Fugue/bwv_860/midi_cleaned.mid
# 26     Bach/Fugue/bwv_860/midi_cleaned.mid
# 27     Bach/Fugue/bwv_860/midi_cleaned.mid
# 28     Bach/Fugue/bwv_860/midi_cleaned.mid
# 29     Bach/Fugue/bwv_860/midi_cleaned.mid
# ..                                     ...
# 136  Bach/Prelude/bwv_874/midi_cleaned.mid
# 137  Bach/Prelude/bwv_874/midi_cleaned.mid
# 138  Bach/Prelude/bwv_875/midi_cleaned.mid
# 139  Bach/Prelude/bwv_875/midi_cleaned.mid
# 140  Bach/Prelude/bwv_875/midi_cleaned.mid
# 141  Bach/Prelude/bwv_876/midi_cleaned.mid
# 142  Bach/Prelude/bwv_876/midi_cleaned.mid
# 143  Bach/Prelude/bwv_880/midi_cleaned.mid
# 145  Bach/Prelude/bwv_880/midi_cleaned.mid
# 146  Bach/Prelude/bwv_883/midi_cleaned.mid
# 149  Bach/Prelude/bwv_883/midi_cleaned.mid
# 150  Bach/Prelude/bwv_884/midi_cleaned.mid
# 152  Bach/Prelude/bwv_885/midi_cleaned.mid
# 153  Bach/Prelude/bwv_885/midi_cleaned.mid
# 154  Bach/Prelude/bwv_885/midi_cleaned.mid
# 157  Bach/Prelude/bwv_887/midi_cleaned.mid
# 158  Bach/Prelude/bwv_888/midi_cleaned.mid
# 159  Bach/Prelude/bwv_889/midi_cleaned.mid
# 160  Bach/Prelude/bwv_889/midi_cleaned.mid
# 161  Bach/Prelude/bwv_889/midi_cleaned.mid
# 162  Bach/Prelude/bwv_889/midi_cleaned.mid
# 163  Bach/Prelude/bwv_889/midi_cleaned.mid
# 164  Bach/Prelude/bwv_889/midi_cleaned.mid
# 165  Bach/Prelude/bwv_891/midi_cleaned.mid
# 166  Bach/Prelude/bwv_891/midi_cleaned.mid
# 167  Bach/Prelude/bwv_892/midi_cleaned.mid
# 168  Bach/Prelude/bwv_892/midi_cleaned.mid
# 169  Bach/Prelude/bwv_893/midi_cleaned.mid
# 170  Bach/Prelude/bwv_893/midi_cleaned.mid
# 171  Bach/Prelude/bwv_893/midi_cleaned.mid
#
#                                      score_xml_path            title  \
# 0      Bach/Fugue/bwv_846/musicxml_cleaned.musicxml    Fugue_bwv_846
# 1      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 2      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 3      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 4      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 5      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 6      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 7      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 8      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 9      Bach/Fugue/bwv_848/musicxml_cleaned.musicxml    Fugue_bwv_848
# 10     Bach/Fugue/bwv_854/musicxml_cleaned.musicxml    Fugue_bwv_854
# 11     Bach/Fugue/bwv_854/musicxml_cleaned.musicxml    Fugue_bwv_854
# 12     Bach/Fugue/bwv_854/musicxml_cleaned.musicxml    Fugue_bwv_854
# 13     Bach/Fugue/bwv_854/musicxml_cleaned.musicxml    Fugue_bwv_854
# 14     Bach/Fugue/bwv_854/musicxml_cleaned.musicxml    Fugue_bwv_854
# 15     Bach/Fugue/bwv_856/musicxml_cleaned.musicxml    Fugue_bwv_856
# 16     Bach/Fugue/bwv_857/musicxml_cleaned.musicxml    Fugue_bwv_857
# 17     Bach/Fugue/bwv_857/musicxml_cleaned.musicxml    Fugue_bwv_857
# 18     Bach/Fugue/bwv_857/musicxml_cleaned.musicxml    Fugue_bwv_857
# 19     Bach/Fugue/bwv_857/musicxml_cleaned.musicxml    Fugue_bwv_857
# 20     Bach/Fugue/bwv_857/musicxml_cleaned.musicxml    Fugue_bwv_857
# 21     Bach/Fugue/bwv_857/musicxml_cleaned.musicxml    Fugue_bwv_857
# 22     Bach/Fugue/bwv_858/musicxml_cleaned.musicxml    Fugue_bwv_858
# 23     Bach/Fugue/bwv_858/musicxml_cleaned.musicxml    Fugue_bwv_858
# 24     Bach/Fugue/bwv_860/musicxml_cleaned.musicxml    Fugue_bwv_860
# 25     Bach/Fugue/bwv_860/musicxml_cleaned.musicxml    Fugue_bwv_860
# 26     Bach/Fugue/bwv_860/musicxml_cleaned.musicxml    Fugue_bwv_860
# 27     Bach/Fugue/bwv_860/musicxml_cleaned.musicxml    Fugue_bwv_860
# 28     Bach/Fugue/bwv_860/musicxml_cleaned.musicxml    Fugue_bwv_860
# 29     Bach/Fugue/bwv_860/musicxml_cleaned.musicxml    Fugue_bwv_860
# ..                                              ...              ...
# 136  Bach/Prelude/bwv_874/musicxml_cleaned.musicxml  Prelude_bwv_874
# 137  Bach/Prelude/bwv_874/musicxml_cleaned.musicxml  Prelude_bwv_874
# 138  Bach/Prelude/bwv_875/musicxml_cleaned.musicxml  Prelude_bwv_875
# 139  Bach/Prelude/bwv_875/musicxml_cleaned.musicxml  Prelude_bwv_875
# 140  Bach/Prelude/bwv_875/musicxml_cleaned.musicxml  Prelude_bwv_875
# 141  Bach/Prelude/bwv_876/musicxml_cleaned.musicxml  Prelude_bwv_876
# 142  Bach/Prelude/bwv_876/musicxml_cleaned.musicxml  Prelude_bwv_876
# 143  Bach/Prelude/bwv_880/musicxml_cleaned.musicxml  Prelude_bwv_880
# 145  Bach/Prelude/bwv_880/musicxml_cleaned.musicxml  Prelude_bwv_880
# 146  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883
# 149  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883
# 150  Bach/Prelude/bwv_884/musicxml_cleaned.musicxml  Prelude_bwv_884
# 152  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 153  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 154  Bach/Prelude/bwv_885/musicxml_cleaned.musicxml  Prelude_bwv_885
# 157  Bach/Prelude/bwv_887/musicxml_cleaned.musicxml  Prelude_bwv_887
# 158  Bach/Prelude/bwv_888/musicxml_cleaned.musicxml  Prelude_bwv_888
# 159  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 160  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 161  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 162  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 163  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 164  Bach/Prelude/bwv_889/musicxml_cleaned.musicxml  Prelude_bwv_889
# 165  Bach/Prelude/bwv_891/musicxml_cleaned.musicxml  Prelude_bwv_891
# 166  Bach/Prelude/bwv_891/musicxml_cleaned.musicxml  Prelude_bwv_891
# 167  Bach/Prelude/bwv_892/musicxml_cleaned.musicxml  Prelude_bwv_892
# 168  Bach/Prelude/bwv_892/musicxml_cleaned.musicxml  Prelude_bwv_892
# 169  Bach/Prelude/bwv_893/musicxml_cleaned.musicxml  Prelude_bwv_893
# 170  Bach/Prelude/bwv_893/musicxml_cleaned.musicxml  Prelude_bwv_893
# 171  Bach/Prelude/bwv_893/musicxml_cleaned.musicxml  Prelude_bwv_893
#
#                                           maestro_path  \
# 0    2006/MIDI-Unprocessed_19_R1_2006_01-07_ORIG_MI...
# 1    2008/MIDI-Unprocessed_02_R1_2008_01-05_ORIG_MI...
# 2    2011/MIDI-Unprocessed_08_R1_2011_MID--AUDIO_R1...
# 3    2017/MIDI-Unprocessed_049_PIANO049_MID--AUDIO-...
# 4    2008/MIDI-Unprocessed_10_R1_2008_01-04_ORIG_MI...
# 5    2011/MIDI-Unprocessed_24_R1_2011_MID--AUDIO_R1...
# 6    2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-fr...
# 7    2011/MIDI-Unprocessed_12_R1_2011_MID--AUDIO_R1...
# 8    2017/MIDI-Unprocessed_059_PIANO059_MID--AUDIO-...
# 9    2011/MIDI-Unprocessed_04_R1_2011_MID--AUDIO_R1...
# 10   2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 11   2017/MIDI-Unprocessed_051_PIANO051_MID--AUDIO-...
# 12   2011/MIDI-Unprocessed_03_R1_2011_MID--AUDIO_R1...
# 13   2013/ORIG-MIDI_02_7_6_13_Group__MID--AUDIO_08_...
# 14   2017/MIDI-Unprocessed_041_PIANO041_MID--AUDIO-...
# 15   2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 16   2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 17   2011/MIDI-Unprocessed_05_R1_2011_MID--AUDIO_R1...
# 18   2008/MIDI-Unprocessed_11_R1_2008_01-04_ORIG_MI...
# 19   2017/MIDI-Unprocessed_048_PIANO048_MID--AUDIO-...
# 20   2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-f...
# 21   2017/MIDI-Unprocessed_042_PIANO042_MID--AUDIO-...
# 22   2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 23   2011/MIDI-Unprocessed_07_R1_2011_MID--AUDIO_R1...
# 24   2008/MIDI-Unprocessed_07_R1_2008_01-04_ORIG_MI...
# 25   2008/MIDI-Unprocessed_12_R1_2008_01-04_ORIG_MI...
# 26   2008/MIDI-Unprocessed_15_R1_2008_01-04_ORIG_MI...
# 27   2017/MIDI-Unprocessed_057_PIANO057_MID--AUDIO-...
# 28   2015/MIDI-Unprocessed_R1_D2-21-22_mid--AUDIO-f...
# 29   2008/MIDI-Unprocessed_18_R1_2008_01-04_ORIG_MI...
# ..                                                 ...
# 136  2011/MIDI-Unprocessed_01_R1_2011_MID--AUDIO_R1...
# 137  2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-f...
# 138  2011/MIDI-Unprocessed_14_R1_2011_MID--AUDIO_R1...
# 139  2017/MIDI-Unprocessed_065_PIANO065_MID--AUDIO-...
# 140  2004/MIDI-Unprocessed_XP_09_R1_2004_01-02_ORIG...
# 141  2017/MIDI-Unprocessed_061_PIANO061_MID--AUDIO-...
# 142  2011/MIDI-Unprocessed_13_R1_2011_MID--AUDIO_R1...
# 143  2017/MIDI-Unprocessed_066_PIANO066_MID--AUDIO-...
# 145  2008/MIDI-Unprocessed_16_R1_2008_01-04_ORIG_MI...
# 146  2017/MIDI-Unprocessed_050_PIANO050_MID--AUDIO-...
# 149  2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-fr...
# 150  2017/MIDI-Unprocessed_060_PIANO060_MID--AUDIO-...
# 152  2011/MIDI-Unprocessed_20_R1_2011_MID--AUDIO_R1...
# 153  2008/MIDI-Unprocessed_04_R1_2008_01-04_ORIG_MI...
# 154  2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-f...
# 157  2015/MIDI-Unprocessed_R1_D1-1-8_mid--AUDIO-fro...
# 158  2015/MIDI-Unprocessed_R1_D2-13-20_mid--AUDIO-f...
# 159  2011/MIDI-Unprocessed_15_R1_2011_MID--AUDIO_R1...
# 160  2017/MIDI-Unprocessed_054_PIANO054_MID--AUDIO-...
# 161  2015/MIDI-Unprocessed_R1_D1-9-12_mid--AUDIO-fr...
# 162  2011/MIDI-Unprocessed_06_R1_2011_MID--AUDIO_R1...
# 163  2017/MIDI-Unprocessed_052_PIANO052_MID--AUDIO-...
# 164  2017/MIDI-Unprocessed_062_PIANO062_MID--AUDIO-...
# 165  2004/MIDI-Unprocessed_XP_03_R1_2004_01-02_ORIG...
# 166  2008/MIDI-Unprocessed_03_R1_2008_01-04_ORIG_MI...
# 167  2011/MIDI-Unprocessed_09_R1_2011_MID--AUDIO_R1...
# 168  2017/MIDI-Unprocessed_055_PIANO055_MID--AUDIO-...
# 169  2008/MIDI-Unprocessed_06_R1_2008_01-04_ORIG_MI...
# 170  2008/MIDI-Unprocessed_09_R1_2008_01-05_ORIG_MI...
# 171  2013/ORIG-MIDI_03_7_6_13_Group__MID--AUDIO_10_...
#
#               maestro_alignment
# 0    (144.06770833333331, None)
# 1     (68.81770833333333, None)
# 2     (74.29557291666666, None)
# 3     (83.14479166666666, None)
# 4     (74.87369791666666, None)
# 5     (75.05729166666666, None)
# 6     (79.11354166666666, None)
# 7              (72.40625, None)
# 8             (70.103125, None)
# 9             (68.296875, None)
# 10    (91.27916666666667, None)
# 11            (82.271875, None)
# 12    (85.43880208333333, None)
# 13    (94.12239583333333, None)
# 14               (86.275, None)
# 15            (59.478125, None)
# 16   (106.57395833333334, None)
# 17                 (None, None)
# 18          (112.8984375, None)
# 19   (132.40833333333333, None)
# 20   (137.13854166666667, None)
# 21   (116.39166666666667, None)
# 22    (83.38229166666666, None)
# 23    (89.83072916666666, None)
# 24    (50.41145833333333, None)
# 25   (50.467447916666664, None)
# 26   (50.506510416666664, None)
# 27                 (51.8, None)
# 28    (51.33958333333333, None)
# 29   (50.752604166666664, None)
# ..                          ...
# 136                (None, None)
# 137  (None, 169.27604166666666)
# 138         (None, 95.73828125)
# 139   (None, 88.54270833333334)
# 140   (None, 88.13541666666667)
# 141  (None, 131.15416666666667)
# 142  (None, 134.52083333333331)
# 143  (None, 206.69583333333333)
# 145        (None, 168.15234375)
# 146  (None, 174.56458333333333)
# 149  (None, 164.54583333333332)
# 150           (None, 70.596875)
# 152  (None, 147.50130208333331)
# 153        (None, 159.19921875)
# 154           (None, 176.94375)
# 157  (None, 112.93645833333333)
# 158  (None, 103.08854166666667)
# 159  (None, 144.83333333333331)
# 160          (None, 138.490625)
# 161  (None, 138.36354166666666)
# 162  (None, 149.01041666666666)
# 163          (None, 131.140625)
# 164  (None, 123.76979166666666)
# 165  (None, 155.61458333333334)
# 166  (None, 141.73697916666666)
# 167  (None, 100.47916666666666)
# 168  (None, 113.53020833333333)
# 169  (None, 130.49869791666666)
# 170  (None, 135.67447916666666)
# 171         (None, 147.3203125)
#
# [150 rows x 11 columns]

# %% [markdown]
# ## Bach

# %%
bach_df = df[df["author"]== "Bach"]
warnings = bach_df.apply(perform_row_to_annotations, axis = 1)
# Out:
# Processing opus Bach/Fugue/bwv_846
# missing corrispondency at quant time 2.5
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_848
# done
# Processing opus Bach/Fugue/bwv_854
# missing corrispondency at quant time 1.5
# done
# Processing opus Bach/Fugue/bwv_854
# missing corrispondency at quant time 1.5
# done
# Processing opus Bach/Fugue/bwv_854
# missing corrispondency at quant time 1.5
# done
# Processing opus Bach/Fugue/bwv_854
# missing corrispondency at quant time 1.5
# done
# Processing opus Bach/Fugue/bwv_854
# missing corrispondency at quant time 1.5
# done
# Processing opus Bach/Fugue/bwv_856
# done
# Processing opus Bach/Fugue/bwv_857
# missing corrispondency at quant time 5.5
# missing corrispondency at quant time 12.0
# missing corrispondency at quant time 17.5
# missing corrispondency at quant time 113.5
# done
# Processing opus Bach/Fugue/bwv_857
# missing corrispondency at quant time 5.5
# missing corrispondency at quant time 12.0
# missing corrispondency at quant time 113.5
# done
# Processing opus Bach/Fugue/bwv_857
# missing corrispondency at quant time 5.5
# missing corrispondency at quant time 11.5
# missing corrispondency at quant time 113.5
# done
# Processing opus Bach/Fugue/bwv_857
# missing corrispondency at quant time 5.5
# missing corrispondency at quant time 12.0
# missing corrispondency at quant time 113.5
# done
# Processing opus Bach/Fugue/bwv_857
# missing corrispondency at quant time 5.5
# missing corrispondency at quant time 113.5
# done
# Processing opus Bach/Fugue/bwv_857
# missing corrispondency at quant time 5.5
# missing corrispondency at quant time 12.0
# missing corrispondency at quant time 113.5
# done
# Processing opus Bach/Fugue/bwv_858
# missing corrispondency at quant time 2.5
# done
# Processing opus Bach/Fugue/bwv_858
# missing corrispondency at quant time 2.5
# done
# Processing opus Bach/Fugue/bwv_860
# missing corrispondency at quant time 94.5
# done
# Processing opus Bach/Fugue/bwv_860
# done
# Processing opus Bach/Fugue/bwv_860
# done
# Processing opus Bach/Fugue/bwv_860
# missing corrispondency at quant time 96.0
# done
# Processing opus Bach/Fugue/bwv_860
# done
# Processing opus Bach/Fugue/bwv_860
# done
# Processing opus Bach/Fugue/bwv_862
# done
# Processing opus Bach/Fugue/bwv_863
# done
# Processing opus Bach/Fugue/bwv_863
# done
# Processing opus Bach/Fugue/bwv_863
# done
# Processing opus Bach/Fugue/bwv_864
# missing corrispondency at quant time 0.75
# done
# Processing opus Bach/Fugue/bwv_865
# missing corrispondency at quant time 3.5
# missing corrispondency at quant time 158.5
# missing corrispondency at quant time 163.5
# done
# Processing opus Bach/Fugue/bwv_865
# missing corrispondency at quant time 3.5
# missing corrispondency at quant time 158.5
# missing corrispondency at quant time 163.5
# done
# Processing opus Bach/Fugue/bwv_865
# missing corrispondency at quant time 3.5
# missing corrispondency at quant time 158.5
# missing corrispondency at quant time 163.5
# done
# Processing opus Bach/Fugue/bwv_867
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_867
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_868
# missing corrispondency at quant time 3.5
# done
# Processing opus Bach/Fugue/bwv_870
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_870
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_870
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_873
# done
# Processing opus Bach/Fugue/bwv_874
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_874
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_875
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_875
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_876
# missing corrispondency at quant time 1.0
# missing corrispondency at quant time 3.0
# missing corrispondency at quant time 5.0
# missing corrispondency at quant time 9.0
# done
# Processing opus Bach/Fugue/bwv_876
# missing corrispondency at quant time 1.0
# missing corrispondency at quant time 3.0
# missing corrispondency at quant time 5.0
# missing corrispondency at quant time 9.0
# done
# Processing opus Bach/Fugue/bwv_880
# done
# Processing opus Bach/Fugue/bwv_880
# done
# Processing opus Bach/Fugue/bwv_883
# missing corrispondency at quant time 2.0
# missing corrispondency at quant time 3.0
# missing corrispondency at quant time 4.0
# missing corrispondency at quant time 5.0
# missing corrispondency at quant time 12.0
# done
# Processing opus Bach/Fugue/bwv_883
# missing corrispondency at quant time 2.0
# missing corrispondency at quant time 3.0
# missing corrispondency at quant time 4.0
# missing corrispondency at quant time 5.0
# missing corrispondency at quant time 11.5
# missing corrispondency at quant time 12.0
# done
# Processing opus Bach/Fugue/bwv_884
# done
# Processing opus Bach/Fugue/bwv_885
# missing corrispondency at quant time 1.0
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 4.0
# missing corrispondency at quant time 108.5
# missing corrispondency at quant time 109.5
# missing corrispondency at quant time 116.0
# missing corrispondency at quant time 117.0
# done
# Processing opus Bach/Fugue/bwv_885
# missing corrispondency at quant time 1.0
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 4.0
# missing corrispondency at quant time 108.5
# missing corrispondency at quant time 109.5
# missing corrispondency at quant time 116.0
# missing corrispondency at quant time 117.0
# done
# Processing opus Bach/Fugue/bwv_885
# missing corrispondency at quant time 1.0
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 4.0
# missing corrispondency at quant time 108.5
# missing corrispondency at quant time 109.5
# missing corrispondency at quant time 116.0
# missing corrispondency at quant time 117.0
# done
# Processing opus Bach/Fugue/bwv_887
# done
# Processing opus Bach/Fugue/bwv_888
# missing corrispondency at quant time 1.5
# missing corrispondency at quant time 2.0
# done
# Processing opus Bach/Fugue/bwv_889
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_889
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_889
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_889
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_889
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_889
# missing corrispondency at quant time 2.5
# missing corrispondency at quant time 3.0
# done
# Processing opus Bach/Fugue/bwv_891
# missing corrispondency at quant time 2.0
# missing corrispondency at quant time 5.0
# missing corrispondency at quant time 10.0
# missing corrispondency at quant time 271.0
# missing corrispondency at quant time 272.0
# missing corrispondency at quant time 273.0
# missing corrispondency at quant time 276.0
# missing corrispondency at quant time 278.0
# missing corrispondency at quant time 280.0
# missing corrispondency at quant time 281.0
# missing corrispondency at quant time 282.0
# missing corrispondency at quant time 283.0
# missing corrispondency at quant time 284.0
# missing corrispondency at quant time 294.0
# missing corrispondency at quant time 295.0
# missing corrispondency at quant time 296.0
# missing corrispondency at quant time 297.0
# missing corrispondency at quant time 298.0
# missing corrispondency at quant time 299.0
# done
# Processing opus Bach/Fugue/bwv_891
# missing corrispondency at quant time 2.0
# missing corrispondency at quant time 5.0
# missing corrispondency at quant time 10.0
# done
# Processing opus Bach/Fugue/bwv_892
# done
# Processing opus Bach/Fugue/bwv_892
# done
# Processing opus Bach/Fugue/bwv_893
# done
# Processing opus Bach/Fugue/bwv_893
# done
# Processing opus Bach/Fugue/bwv_893
# done
# Processing opus Bach/Prelude/bwv_846
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_848
# done
# Processing opus Bach/Prelude/bwv_854
# done
# Processing opus Bach/Prelude/bwv_854
# done
# Processing opus Bach/Prelude/bwv_854
# done
# Processing opus Bach/Prelude/bwv_854
# done
# Processing opus Bach/Prelude/bwv_854
# missing corrispondency at quant time 68.25
# done
# Processing opus Bach/Prelude/bwv_856
# done
# Processing opus Bach/Prelude/bwv_857
# missing corrispondency at quant time 4.0
# done
# Processing opus Bach/Prelude/bwv_857
# missing corrispondency at quant time 20.0
# done
# Processing opus Bach/Prelude/bwv_857
# missing corrispondency at quant time 19.0
# done
# Processing opus Bach/Prelude/bwv_857
# done
# Processing opus Bach/Prelude/bwv_857
# done
# Processing opus Bach/Prelude/bwv_857
# done
# Processing opus Bach/Prelude/bwv_858
# done
# Processing opus Bach/Prelude/bwv_858
# missing corrispondency at quant time 27.75
# done
# Processing opus Bach/Prelude/bwv_860
# done
# Processing opus Bach/Prelude/bwv_860
# done
# Processing opus Bach/Prelude/bwv_860
# done
# Processing opus Bach/Prelude/bwv_860
# done
# Processing opus Bach/Prelude/bwv_860
# done
# Processing opus Bach/Prelude/bwv_860
# done
# Processing opus Bach/Prelude/bwv_862
# missing corrispondency at quant time 60.5
# missing corrispondency at quant time 62.0
# done
# Processing opus Bach/Prelude/bwv_863
# done
# Processing opus Bach/Prelude/bwv_863
# done
# Processing opus Bach/Prelude/bwv_863
# done
# Processing opus Bach/Prelude/bwv_864
# done
# Processing opus Bach/Prelude/bwv_865
# done
# Processing opus Bach/Prelude/bwv_865
# done
# Processing opus Bach/Prelude/bwv_865
# done
# Processing opus Bach/Prelude/bwv_867
# missing corrispondency at quant time 43.5
# done
# Processing opus Bach/Prelude/bwv_867
# missing corrispondency at quant time 43.5
# done
# Processing opus Bach/Prelude/bwv_868
# done
# Processing opus Bach/Prelude/bwv_870
# done
# Processing opus Bach/Prelude/bwv_870
# done
# Processing opus Bach/Prelude/bwv_870
# done
# Processing opus Bach/Prelude/bwv_873
# missing corrispondency at quant time 31.5
# missing corrispondency at quant time 42.0
# missing corrispondency at quant time 89.25
# missing corrispondency at quant time 111.75
# missing corrispondency at quant time 123.0
# missing corrispondency at quant time 132.75
# done
# Processing opus Bach/Prelude/bwv_874
# done
# Processing opus Bach/Prelude/bwv_874
# done
# Processing opus Bach/Prelude/bwv_874
# done
# Processing opus Bach/Prelude/bwv_875
# done
# Processing opus Bach/Prelude/bwv_875
# done
# Processing opus Bach/Prelude/bwv_875
# done
# Processing opus Bach/Prelude/bwv_876
# missing corrispondency at quant time 149.25
# done
# Processing opus Bach/Prelude/bwv_876
# missing corrispondency at quant time 149.25
# done
# Processing opus Bach/Prelude/bwv_880
# done
# Processing opus Bach/Prelude/bwv_880
# done
# Processing opus Bach/Prelude/bwv_883
# missing corrispondency at quant time 42.5
# done
# Processing opus Bach/Prelude/bwv_883
# missing corrispondency at quant time 42.5
# done
# Processing opus Bach/Prelude/bwv_884
# done
# Processing opus Bach/Prelude/bwv_885
# done
# Processing opus Bach/Prelude/bwv_885
# done
# Processing opus Bach/Prelude/bwv_885
# done
# Processing opus Bach/Prelude/bwv_887
# done
# Processing opus Bach/Prelude/bwv_888
# done
# Processing opus Bach/Prelude/bwv_889
# done
# Processing opus Bach/Prelude/bwv_889
# done
# Processing opus Bach/Prelude/bwv_889
# done
# Processing opus Bach/Prelude/bwv_889
# done
# Processing opus Bach/Prelude/bwv_889
# done
# Processing opus Bach/Prelude/bwv_889
# done
# Processing opus Bach/Prelude/bwv_891
# done
# Processing opus Bach/Prelude/bwv_891
# done
# Processing opus Bach/Prelude/bwv_892
# done
# Processing opus Bach/Prelude/bwv_892
# done
# Processing opus Bach/Prelude/bwv_893
# missing corrispondency at quant time 55.00004400000004
# missing corrispondency at quant time 58.33338000000004
# missing corrispondency at quant time 94.16674199999979
# missing corrispondency at quant time 102.50008199999976
# missing corrispondency at quant time 104.16674999999974
# missing corrispondency at quant time 105.83341799999971
# done
# Processing opus Bach/Prelude/bwv_893
# missing corrispondency at quant time 94.16674199999979
# missing corrispondency at quant time 102.50008199999976
# missing corrispondency at quant time 104.16674999999974
# missing corrispondency at quant time 105.83341799999971
# done
# Processing opus Bach/Prelude/bwv_893
# missing corrispondency at quant time 51.666708000000035
# missing corrispondency at quant time 94.16674199999979
# missing corrispondency at quant time 102.50008199999976
# missing corrispondency at quant time 104.16674999999974
# missing corrispondency at quant time 105.83341799999971
# done

# %%
warnings
# Out:
# 0       True
# 1      False
# 2      False
# 3      False
# 4      False
# 5      False
# 6      False
# 7      False
# 8      False
# 9      False
# 10      True
# 11      True
# 12      True
# 13      True
# 14      True
# 15     False
# 16      True
# 17      True
# 18      True
# 19      True
# 20      True
# 21      True
# 22      True
# 23      True
# 24      True
# 25     False
# 26     False
# 27      True
# 28     False
# 29     False
#        ...
# 136    False
# 137    False
# 138    False
# 139    False
# 140    False
# 141     True
# 142     True
# 143    False
# 145    False
# 146     True
# 149     True
# 150    False
# 152    False
# 153    False
# 154    False
# 157    False
# 158    False
# 159    False
# 160    False
# 161    False
# 162    False
# 163    False
# 164    False
# 165    False
# 166    False
# 167    False
# 168    False
# 169     True
# 170     True
# 171     True
# Length: 150, dtype: bool

# %%
# create and save as excel for collaboration
bach_df_excel = bach_df[["author","performed_midi_path"]].copy()
bach_df_excel["done"] = [not e for e in list(warnings)]
bach_df_excel

# uncomment the following to write the file
bach_df_excel.to_excel("performance_bach.xlsx")

# %% [markdown]
# ## Create for a single song

# %%
df[df["folder"]== "Bach/Prelude/bwv_883"]
# Out:
#     author                folder  \
# 146   Bach  Bach/Prelude/bwv_883
# 147   Bach  Bach/Prelude/bwv_883
# 148   Bach  Bach/Prelude/bwv_883
# 149   Bach  Bach/Prelude/bwv_883
#
#                              midi2midi_alignment_path  \
# 146     Bach/Prelude/bwv_883/GuoE01_infer_corresp.txt
# 147  Bach/Prelude/bwv_883/Herbert02_infer_corresp.txt
# 148      Bach/Prelude/bwv_883/Lim01_infer_corresp.txt
# 149      Bach/Prelude/bwv_883/LuM01_infer_corresp.txt
#
#                     performed_midi_path  performer  \
# 146     Bach/Prelude/bwv_883/GuoE01.mid     GuoE01
# 147  Bach/Prelude/bwv_883/Herbert02.mid  Herbert02
# 148      Bach/Prelude/bwv_883/Lim01.mid      Lim01
# 149      Bach/Prelude/bwv_883/LuM01.mid      LuM01
#
#                                score2midi_alignment  \
# 146     Bach/Prelude/bwv_883/GuoE01_infer_match.txt
# 147  Bach/Prelude/bwv_883/Herbert02_infer_match.txt
# 148      Bach/Prelude/bwv_883/Lim01_infer_match.txt
# 149      Bach/Prelude/bwv_883/LuM01_infer_match.txt
#
#                            score_midi_path  \
# 146  Bach/Prelude/bwv_883/midi_cleaned.mid
# 147  Bach/Prelude/bwv_883/midi_cleaned.mid
# 148  Bach/Prelude/bwv_883/midi_cleaned.mid
# 149  Bach/Prelude/bwv_883/midi_cleaned.mid
#
#                                      score_xml_path            title
# 146  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883
# 147  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883
# 148  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883
# 149  Bach/Prelude/bwv_883/musicxml_cleaned.musicxml  Prelude_bwv_883

# %%
song = df.iloc[147]
print(song)
perform_row_to_annotations(song)
# Out:
# author                                                                  Bach
# folder                                                  Bach/Prelude/bwv_883
# midi2midi_alignment_path    Bach/Prelude/bwv_883/Herbert02_infer_corresp.txt
# performed_midi_path                       Bach/Prelude/bwv_883/Herbert02.mid
# performer                                                          Herbert02
# score2midi_alignment          Bach/Prelude/bwv_883/Herbert02_infer_match.txt
# score_midi_path                        Bach/Prelude/bwv_883/midi_cleaned.mid
# score_xml_path                Bach/Prelude/bwv_883/musicxml_cleaned.musicxml
# title                                                        Prelude_bwv_883
# Name: 147, dtype: object
# Processing opus Bach/Prelude/bwv_883
# missing corrispondency at quant time 0.0
# missing corrispondency at quant time 42.5
# ind 1
# filling index 0 with number 0
# annotations cleaned:  {0: 'dbW', 0.516026: 'b', 2.053955: 'b', 3.550933333333333: 'db', 5.078: 'b', 6.603105: 'b', 8.024045000000001: 'db', 9.597233333333334: 'b', 11.1681: 'b', 12.809833333333335: 'db', 14.481133333333334: 'b', 16.0732: 'b', 17.5353: 'db', 19.07425: 'b', 20.5406: 'b', 21.8462: 'db', 23.171: 'b', 24.55185: 'b', 26.4984: 'db', 28.1955: 'b', 29.6592: 'b', 31.1982: 'db', 32.7826: 'b', 34.24575: 'b', 35.5823: 'db', 37.317899999999995: 'b', 38.849900000000005: 'b', 40.33765: 'db', 41.8141: 'b', 43.33925: 'b', 44.8398: 'db', 46.359: 'b', 47.9333: 'b', 49.513400000000004: 'db', 51.1325: 'b', 52.632000000000005: 'b', 54.08089999999999: 'db', 55.5663: 'b', 57.0038: 'b', 58.3793: 'db', 59.9199: 'b', 61.3238: 'b', 62.7896: 'db', 64.26554999999999: 'b', 65.61545: 'b', 67.08765: 'db', 68.6892: 'b', 70.1486: 'b', 71.62825000000001: 'db', 73.0914: 'b', 74.56895: 'b', 76.0855: 'db', 77.51185: 'b', 78.98515: 'b', 80.48140000000001: 'db', 81.94295: 'b', 83.4114: 'b', 84.89999999999999: 'db', 86.40875: 'b', 87.86545: 'b', 89.4039: 'db', 90.8398: 'b', 92.30725: 'b', 93.85196666666667: 'db', 95.36796666666667: 'b', 96.87259999999999: 'b', 98.33179999999999: 'db', 99.7202: 'b', 101.11399999999999: 'b', 102.60366666666665: 'db', 104.13833333333334: 'b', 105.62: 'b', 107.089: 'db', 108.495: 'b', 109.93350000000001: 'b', 111.46449999999999: 'db', 112.9805: 'b', 114.428: 'b', 115.96866666666666: 'db', 117.486: 'b', 118.97200000000001: 'b', 120.714: 'db', 122.339: 'b', 123.97266666666667: 'b', 125.98049999999999: 'db', 128.13725: 'bW', 130.29399999999998: 'b', 132.1115: 'db', 133.733: 'b', 135.3075: 'b', 136.82366666666667: 'db', 138.375: 'b', 139.8305: 'b', 141.231: 'db', 142.8: 'b', 144.31966666666665: 'b', 145.879: 'db', 147.35766666666666: 'b', 148.87666666666667: 'b', 150.44766666666666: 'db', 152.039: 'b', 153.49333333333334: 'b', 154.905: 'db', 156.238: 'b', 157.62966666666668: 'b', 159.144: 'db', 160.7135: 'b', 162.21300000000002: 'b', 163.66166666666666: 'db', 165.0235: 'b', 166.3865: 'b', 167.81733333333332: 'db', 169.28566666666666: 'b', 170.721: 'b', 172.20399999999998: 'db', 173.59550000000002: 'b', 175.0025: 'b', 176.49: 'db', 177.9435: 'b', 179.34: 'b', 181.017: 'db', 182.6206666666667: 'b', 184.058: 'b', 185.49: 'db', 186.96550000000002: 'b', 188.783: 'b', 192.08766666666665: 'db'}
# db: [0, 3.550933333333333, 8.024045000000001, 12.809833333333335, 17.5353, 21.8462, 26.4984, 31.1982, 35.5823, 40.33765, 44.8398, 49.513400000000004, 54.08089999999999, 58.3793, 62.7896, 67.08765, 71.62825000000001, 76.0855, 80.48140000000001, 84.89999999999999, 89.4039, 93.85196666666667, 98.33179999999999, 102.60366666666665, 107.089, 111.46449999999999, 115.96866666666666, 120.714, 125.98049999999999, 132.1115, 136.82366666666667, 141.231, 145.879, 150.44766666666666, 154.905, 159.144, 163.66166666666666, 167.81733333333332, 172.20399999999998, 176.49, 181.017, 185.49, 192.08766666666665]
# done
# 'True'
